# %% [markdown]
# # Imports

# %%
import pandas as pd
import random
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import optuna

from itertools import product
from tqdm import tqdm 
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Initial test

# %%
# Load the dataset
data = pd.read_csv('../data/synthetic_time_series.csv')

# Convert timestamp to datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data['timestamp'], y=data['kpi'], mode='lines', name='KPI'))
fig.update_layout(title='Time-Series Data', xaxis_title='Time', yaxis_title='KPI Value')
fig.show()

# %%
# Normalize KPI values
scaler = MinMaxScaler()
data['kpi_normalized'] = scaler.fit_transform(data[['kpi']])

# %%
# Split into 80% training and 20% testing
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Initialize and train the model
model = IsolationForest(contamination=0.02, random_state=42)
model.fit(train_data[['kpi_normalized']])

# Predict anomalies on the test set
test_data['anomaly'] = model.predict(test_data[['kpi_normalized']])

# Map predictions: 1 (normal), -1 (anomaly)
test_data['anomaly'] = test_data['anomaly'].map({1: 0, -1: 1})

# %%
# Extract anomalies
anomalies = test_data[test_data['anomaly'] == 1]

# %%
# Sort data by timestamp
test_data = test_data.sort_values(by='timestamp')

# Extract anomalies after sorting
anomalies = test_data[test_data['anomaly'] == 1]

# %%
# Plot the KPI values and anomalies
fig = go.Figure()
fig.add_trace(go.Scatter(x=test_data['timestamp'], y=test_data['kpi'], mode='lines', name='KPI'))
fig.add_trace(go.Scatter(x=anomalies['timestamp'], y=anomalies['kpi'], mode='markers', name='Anomalies', marker=dict(color='red')))
fig.update_layout(title='Detected Anomalies in KPI Data', xaxis_title='Time', yaxis_title='KPI Value')
fig.show()

# %% [markdown]
# # Refining

# %%
# Filter anomalies based on KPI value threshold (e.g., 0.6)
HIGH_KPI_THRESHOLD = 0.6
test_data['anomaly'] = test_data.apply(
    lambda row: 1 if row['anomaly'] == 1 and row['kpi'] > HIGH_KPI_THRESHOLD else 0,
    axis=1
)

# Extract anomalies
anomalies = test_data[test_data['anomaly'] == 1]

# %%
# Create the main line plot for KPI values
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=test_data['timestamp'],
    y=test_data['kpi'],
    mode='lines',
    name='KPI',
    line=dict(color='blue', width=2)
))

# Add anomalies as a scatter plot
fig.add_trace(go.Scatter(
    x=anomalies['timestamp'],
    y=anomalies['kpi'],
    mode='markers',
    name='Anomalies',
    marker=dict(color='red', size=10, symbol='circle'),
    hoverinfo='x+y'
))

# Update layout for better readability
fig.update_layout(
    title='Detected Anomalies in KPI Data (High Values Only)',
    xaxis_title='Time',
    yaxis_title='KPI Value',
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
    template='plotly_white'
)

fig.show()

# %% [markdown]
# # False Alarm Rate

# %%
# Load the dataset
data = pd.read_csv('../data/synthetic_time_series.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Set the False Alarm Rate (e.g., 1%)
FAR = 0.01

# Calculate the threshold based on FAR
threshold = np.quantile(data['kpi'], 1 - FAR)

# Identify anomalies based on the threshold
data['anomaly'] = data['kpi'].apply(lambda x: 1 if x > threshold else 0)

# Extract anomalies for visualization
anomalies = data[data['anomaly'] == 1]

# Display the threshold value
print(f"Anomaly threshold (based on FAR={FAR}): {threshold}")
# Out:
# Anomaly threshold (based on FAR=0.01): 0.7594836744255726

# %%
# Create the main line plot for KPI values
fig = go.Figure()

# Add the KPI line plot
fig.add_trace(go.Scatter(
    x=data['timestamp'],
    y=data['kpi'],
    mode='lines',
    name='KPI',
    line=dict(color='blue', width=2)
))

# Add anomalies as a scatter plot
fig.add_trace(go.Scatter(
    x=anomalies['timestamp'],
    y=anomalies['kpi'],
    mode='markers',
    name='Anomalies',
    marker=dict(color='red', size=10, symbol='circle'),
    hoverinfo='x+y'
))

# Add a horizontal line for the threshold
fig.add_trace(go.Scatter(
    x=data['timestamp'],
    y=[threshold] * len(data),
    mode='lines',
    name='Threshold',
    line=dict(color='green', width=2, dash='dash')
))

# Update layout for better visualization
fig.update_layout(
    title='Anomaly Detection Using False Alarm Rate',
    xaxis_title='Time',
    yaxis_title='KPI Value',
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
    template='plotly_white'
)

fig.show()

# %% [markdown]
# # Cell-Averaging Constant False Alarm Rate (CA-CFAR)

# %%
# Load the dataset
data = pd.read_csv('../data/synthetic_time_series.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Define CA-CFAR parameters
REFERENCE_CELLS = 20  # Number of reference cells
GUARD_CELLS = 5       # Number of guard cells
FAR = 0.01            # False alarm rate

# Initialize variables
kpi_values = data['kpi'].values
num_points = len(kpi_values)
thresholds = np.zeros(num_points)
anomalies = np.zeros(num_points)

# CA-CFAR processing
for i in range(num_points):
    # Define the sliding window
    start_idx = max(0, i - REFERENCE_CELLS - GUARD_CELLS)
    end_idx = min(num_points, i + REFERENCE_CELLS + GUARD_CELLS + 1)
    guard_start_idx = max(0, i - GUARD_CELLS)
    guard_end_idx = min(num_points, i + GUARD_CELLS + 1)

    # Exclude guard cells and the current cell
    reference_cells = np.concatenate([
        kpi_values[start_idx:guard_start_idx],
        kpi_values[guard_end_idx:end_idx]
    ])
    
    # Calculate the threshold based on the reference cells
    if len(reference_cells) > 0:
        noise_level = np.mean(reference_cells)
        threshold = noise_level * (1 + FAR)  # Adjust with FAR
        thresholds[i] = threshold

        # Detect anomalies
        if kpi_values[i] > threshold:
            anomalies[i] = 1

# Add results to the DataFrame
data['threshold'] = thresholds
data['anomaly'] = anomalies

# Extract anomalies for visualization
anomalies_df = data[data['anomaly'] == 1]

# %%
# Create the main line plot for KPI values
fig = go.Figure()

# Add KPI line plot
fig.add_trace(go.Scatter(
    x=data['timestamp'],
    y=data['kpi'],
    mode='lines',
    name='KPI',
    line=dict(color='blue', width=2)
))

# Add anomalies as scatter points
fig.add_trace(go.Scatter(
    x=anomalies_df['timestamp'],
    y=anomalies_df['kpi'],
    mode='markers',
    name='Anomalies',
    marker=dict(color='red', size=10, symbol='circle'),
    hoverinfo='x+y'
))

# Add dynamic threshold plot
fig.add_trace(go.Scatter(
    x=data['timestamp'],
    y=data['threshold'],
    mode='lines',
    name='Dynamic Threshold',
    line=dict(color='green', width=2, dash='dash')
))

# Update layout for better visualization
fig.update_layout(
    title='Anomaly Detection Using CA-CFAR',
    xaxis_title='Time',
    yaxis_title='KPI Value',
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
    template='plotly_white'
)

fig.show()

# %%
num_anomalies = np.sum(anomalies)
print(f"Number of anomalies: {num_anomalies}")
# Out:
# Number of anomalies: 246.0

# %%
# Update CA-CFAR parameters
REFERENCE_CELLS = 40  # Increase reference cells for better noise estimation
GUARD_CELLS = 10      # Increase guard cells to exclude nearby anomalies
FAR = 0.005           # Lower False Alarm Rate for stricter threshold
THRESHOLD_MARGIN = 1.5  # Additional multiplier to make the threshold stricter

# Reinitialize variables
thresholds = np.zeros(num_points)
anomalies = np.zeros(num_points)

# CA-CFAR processing with updated parameters
for i in range(num_points):
    # Define the sliding window
    start_idx = max(0, i - REFERENCE_CELLS - GUARD_CELLS)
    end_idx = min(num_points, i + REFERENCE_CELLS + GUARD_CELLS + 1)
    guard_start_idx = max(0, i - GUARD_CELLS)
    guard_end_idx = min(num_points, i + GUARD_CELLS + 1)

    # Exclude guard cells and the current cell
    reference_cells = np.concatenate([
        kpi_values[start_idx:guard_start_idx],
        kpi_values[guard_end_idx:end_idx]
    ])
    
    # Calculate the threshold based on the reference cells
    if len(reference_cells) > 0:
        noise_level = np.mean(reference_cells)
        threshold = noise_level * (1 + FAR) * THRESHOLD_MARGIN  # Add margin multiplier
        thresholds[i] = threshold

        # Detect anomalies
        if kpi_values[i] > threshold:
            anomalies[i] = 1

# Update the DataFrame with results
data['threshold'] = thresholds
data['anomaly'] = anomalies

# Count the number of anomalies
num_anomalies = np.sum(anomalies)
print(f"Number of anomalies: {num_anomalies}")
# Out:
# Number of anomalies: 59.0

# %%
def visualize_cfar_results(data, title="CA-CFAR Anomaly Detection Results"):
    """
    Visualizes KPI values, dynamic thresholds, and anomalies.

    Parameters:
        data (DataFrame): DataFrame with 'timestamp', 'kpi', 'threshold', and 'anomaly' columns.
        title (str): Title for the plot.
    """
    # Extract anomalies
    anomalies = data[data['anomaly'] == 1]

    # Create the main line plot for KPI values
    fig = go.Figure()

    # Add KPI line plot
    fig.add_trace(go.Scatter(
        x=data['timestamp'],
        y=data['kpi'],
        mode='lines',
        name='KPI',
        line=dict(color='blue', width=2)
    ))

    # Add anomalies as scatter points
    fig.add_trace(go.Scatter(
        x=anomalies['timestamp'],
        y=anomalies['kpi'],
        mode='markers',
        name='Anomalies',
        marker=dict(color='red', size=10, symbol='circle'),
        hoverinfo='x+y'
    ))

    # Add dynamic threshold plot
    fig.add_trace(go.Scatter(
        x=data['timestamp'],
        y=data['threshold'],
        mode='lines',
        name='Dynamic Threshold',
        line=dict(color='green', width=2, dash='dash')
    ))

    # Update layout for better visualization
    fig.update_layout(
        title=title,
        xaxis_title='Time',
        yaxis_title='KPI Value',
        legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
        template='plotly_white'
    )

    # Show the plot
    fig.show()

# %%
visualize_cfar_results(data, title="CA-CFAR Tuned Results")

# %%
# Update GO-CFAR parameters
REFERENCE_CELLS = 20  # Number of reference cells on each side
GUARD_CELLS = 1      # Guard cells to isolate the target
FAR = 0.005           # False alarm rate
THRESHOLD_MARGIN = 1.7  # Additional margin multiplier

# Reinitialize variables
thresholds = np.zeros(num_points)
anomalies = np.zeros(num_points)

# GO-CFAR processing
for i in range(num_points):
    # Define the sliding window
    start_idx = max(0, i - REFERENCE_CELLS - GUARD_CELLS)
    guard_start_idx = max(0, i - GUARD_CELLS)
    guard_end_idx = min(num_points, i + GUARD_CELLS + 1)
    end_idx = min(num_points, i + REFERENCE_CELLS + GUARD_CELLS + 1)

    # Split reference cells into two groups
    left_reference_cells = kpi_values[start_idx:guard_start_idx]
    right_reference_cells = kpi_values[guard_end_idx:end_idx]

    # Use the maximum average noise level from both groups
    max_noise_level = max(
        np.mean(left_reference_cells) if len(left_reference_cells) > 0 else 0,
        np.mean(right_reference_cells) if len(right_reference_cells) > 0 else 0
    )

    # Calculate the threshold
    threshold = max_noise_level * (1 + FAR) * THRESHOLD_MARGIN
    thresholds[i] = threshold

    # Detect anomalies
    if kpi_values[i] > threshold:
        anomalies[i] = 1

# Update the DataFrame with results
data['threshold'] = thresholds
data['anomaly'] = anomalies

# Count the number of anomalies
num_anomalies = np.sum(anomalies)
print(f"Number of anomalies: {num_anomalies}")
# Out:
# Number of anomalies: 10.0

# %%
anomalies = data[data['anomaly'] == 1]
anomaly_timestamps = anomalies['timestamp']
anomaly_values = anomalies['kpi']
print(anomaly_timestamps)
print(anomaly_values)
# Out:
# 15    2024-01-01 00:15:00
# 40    2024-01-01 00:40:00
# 124   2024-01-01 02:04:00
# 140   2024-01-01 02:20:00
# 187   2024-01-01 03:07:00
# 192   2024-01-01 03:12:00
# 317   2024-01-01 05:17:00
# 358   2024-01-01 05:58:00
# 393   2024-01-01 06:33:00
# 451   2024-01-01 07:31:00
# Name: timestamp, dtype: datetime64[ns]
# 15     0.733400
# 40     0.967942
# 124    0.738538
# 140    0.780887
# 187    0.895000
# 192    0.814958
# 317    0.738781
# 358    0.476092
# 393    0.759267
# 451    0.921141
# Name: kpi, dtype: float64

# %%
visualize_cfar_results(data, title="GO-CFAR Anomaly Detection Results")

# %%
# Define the synthetic anomaly indices (ground truth)
synthetic_anomalies_indices = [15, 40, 124, 140, 187, 192, 317, 358, 393, 451]

# Declare the ground_truth variable
ground_truth = [1 if i in synthetic_anomalies_indices else 0 for i in range(len(data))]

# Add ground truth as a column to the data DataFrame
data['ground_truth'] = ground_truth

# %%
# Calculate the confusion matrix
cm = confusion_matrix(data['ground_truth'], data['anomaly'])

# Display the confusion matrix
print("Confusion Matrix:")
print(cm)

# Calculate accuracy
accuracy = (cm[0, 0] + cm[1, 1]) / np.sum(cm)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Confusion Matrix:
# [[490   0]
#  [  0  10]]
# Accuracy: 1.00

# %%
data
# Out:
#               timestamp       kpi  threshold  anomaly  ground_truth
# 0   2024-01-01 00:00:00  0.249816   0.511875      0.0             0
# 1   2024-01-01 00:01:00  0.480286   0.496845      0.0             0
# 2   2024-01-01 00:02:00  0.392798   0.488907      0.0             0
# 3   2024-01-01 00:03:00  0.339463   0.623689      0.0             0
# 4   2024-01-01 00:04:00  0.162407   0.639491      0.0             0
# ..                  ...       ...        ...      ...           ...
# 495 2024-01-01 08:15:00  0.241341   0.635184      0.0             0
# 496 2024-01-01 08:16:00  0.333462   0.840789      0.0             0
# 497 2024-01-01 08:17:00  0.131094   0.844826      0.0             0
# 498 2024-01-01 08:18:00  0.489758   0.548362      0.0             0
# 499 2024-01-01 08:19:00  0.494484   0.532093      0.0             0
#
# [500 rows x 5 columns]

# %% [markdown]
# # Test 2

# %%
# Load the dataset
data2 = pd.read_csv('../data/synthetic_time_series_hard.csv')
data2['timestamp'] = pd.to_datetime(data2['timestamp'])

# Define the visualization function
def plot_time_series(data, title="Time-Series Data", show_anom=False):
    """
    Plots the time-series data using Plotly.
    
    Parameters:
        data (DataFrame): A DataFrame with 'timestamp' and 'kpi' columns.
        title (str): Title of the plot.
        show_anom (bool): If True, show anomalies with red dots.
    """
    fig = go.Figure()
    
    # Add the KPI line plot
    fig.add_trace(go.Scatter(
        x=data['timestamp'],
        y=data['kpi'],
        mode='lines',
        name='KPI',
        line=dict(color='blue', width=2)
    ))
    
    # Add anomalies as scatter points if show_anom is True
    if show_anom and 'anomaly_true' in data.columns:
        anomalies = data[data['anomaly_true'] == 1]
        fig.add_trace(go.Scatter(
            x=anomalies['timestamp'],
            y=anomalies['kpi'],
            mode='markers',
            name='Anomalies',
            marker=dict(color='red', size=10, symbol='circle'),
            hoverinfo='x+y'
        ))
    
    # Update layout
    fig.update_layout(
        title=title,
        xaxis_title='Time',
        yaxis_title='KPI Value',
        template='plotly_white'
    )
    
    fig.show()

# Visualize the dataset
plot_time_series(data2, title="Synthetic Time-Series with Harder Anomalies")

# %%
data2
# Out:
#                timestamp       kpi
# 0    2024-01-01 00:00:00  0.249816
# 1    2024-01-01 00:01:00  0.480286
# 2    2024-01-01 00:02:00  0.392798
# 3    2024-01-01 00:03:00  0.339463
# 4    2024-01-01 00:04:00  0.962444
# ...                  ...       ...
# 1435 2024-01-01 23:55:00  0.111989
# 1436 2024-01-01 23:56:00  0.223172
# 1437 2024-01-01 23:57:00  0.381872
# 1438 2024-01-01 23:58:00  0.180741
# 1439 2024-01-01 23:59:00  0.369373
#
# [1440 rows x 2 columns]

# %% [markdown]
# ## Model

# %%
def ca_cfar(data_set=None, ref_cells=20, guard_cells=1, far=0.005, margin=1.7):
    if data_set is None:
        print("There has to be a data set on argument")
        return None
    
    kpi_values = data_set['kpi'].values
    num_points = len(kpi_values)
    thresholds = np.zeros(num_points)
    anomalies = np.zeros(num_points)

    for i in range(num_points):
        start_idx = max(0, i - ref_cells - guard_cells)
        guard_start_idx = max(0, i - guard_cells)
        guard_end_idx = min(num_points, i + guard_cells + 1)
        end_idx = min(num_points, i + ref_cells + guard_cells + 1)

        left_reference_cells = kpi_values[start_idx:guard_start_idx]
        right_reference_cells = kpi_values[guard_end_idx:end_idx]

        max_noise_level = max(
            np.mean(left_reference_cells) if len(left_reference_cells) > 0 else 0,
            np.mean(right_reference_cells) if len(right_reference_cells) > 0 else 0
        )

        threshold = max_noise_level * (1 + far) * margin
        thresholds[i] = threshold

        if kpi_values[i] > threshold:
            anomalies[i] = 1

    data_set['threshold'] = thresholds
    data_set['anomaly'] = anomalies
    return data_set

# Apply the function to data2
data2 = ca_cfar(data2, ref_cells=10, guard_cells=1, margin=1.69)

# Count the number of anomalies
num_anomalies = np.sum(data2['anomaly'])
print(f"Number of anomalies: {num_anomalies}")

# Visualize the results using visualize cfar function 
visualize_cfar_results(data2)
# Out:
# Number of anomalies: 99.0

# %%
data2
# Out:
#                timestamp       kpi  threshold  anomaly
# 0    2024-01-01 00:00:00  0.249816   0.834709      0.0
# 1    2024-01-01 00:01:00  0.480286   0.841533      0.0
# 2    2024-01-01 00:02:00  0.392798   0.815287      0.0
# 3    2024-01-01 00:03:00  0.339463   0.681158      0.0
# 4    2024-01-01 00:04:00  0.962444   0.683021      1.0
# ...                  ...       ...        ...      ...
# 1435 2024-01-01 23:55:00  0.111989   0.614267      0.0
# 1436 2024-01-01 23:56:00  0.223172   0.637435      0.0
# 1437 2024-01-01 23:57:00  0.381872   0.627362      0.0
# 1438 2024-01-01 23:58:00  0.180741   0.594488      0.0
# 1439 2024-01-01 23:59:00  0.369373   0.577698      0.0
#
# [1440 rows x 4 columns]

# %% [markdown]
# # Test 3

# %%
# Generate synthetic time-series data for 24 hours (1440 minutes)
time_steps = pd.date_range(start='2024-01-02', periods=1440, freq='min')  # 24 hours
kpi_values = np.random.uniform(0.3, 0.7, size=len(time_steps))  # Normal KPI values

# Introduce 5 harder-to-detect anomalies
anomaly_indices = random.sample(range(len(kpi_values)), 25)
kpi_values[anomaly_indices] = np.random.uniform(0.71, 0.8, size=len(anomaly_indices))  # Slightly higher than normal

# Create a DataFrame with true anomaly labels
synthetic_data_hard_5 = pd.DataFrame({
    'timestamp': time_steps,
    'kpi': kpi_values,
    'anomaly_true': [1 if i in anomaly_indices else 0 for i in range(len(time_steps))]
})

# Save the DataFrame to a CSV file
file_path = '../data/synthetic_time_series_hard_5.csv'
synthetic_data_hard_5.to_csv(file_path, index=False)

print("File created at:", file_path)
# Out:
# File created at: ../data/synthetic_time_series_hard_5.csv

# %%
data5 = pd.read_csv('../data/synthetic_time_series_hard_5.csv') 
plot_time_series(data5, title="Synthetic Time-Series with Harder Anomalies", show_anom=True)

# %%
data_5_cacfar = ca_cfar(data5, margin=1)
visualize_cfar_results(data_5_cacfar, title="CA-CFAR Anomaly Detection Results")

# %%
def calculate_accuracy(data):
    """
    Calculate the accuracy between the columns 'anomaly_true' and 'anomaly'.

    Parameters:
        data (DataFrame): DataFrame containing 'anomaly_true' and 'anomaly' columns.

    Returns:
        float: Accuracy value.
    """
    correct_predictions = (data['anomaly_true'] == data['anomaly']).sum()
    total_predictions = len(data)
    accuracy = correct_predictions / total_predictions
    return accuracy

# Calculate accuracy for data5
accuracy = calculate_accuracy(data5)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5659722222222222

# %%
def grid_search_cafar(data, ref_cells_range, guard_cells_range, far_range, margin_range):
    """
    Effectue une recherche en grille pour optimiser les paramètres du modèle CA-CFAR avec une barre de progression.

    Parameters:
        data (DataFrame): Jeu de données contenant les colonnes 'kpi' et 'anomaly_true'.
        ref_cells_range (list): Liste des valeurs pour REFERENCE_CELLS.
        guard_cells_range (list): Liste des valeurs pour GUARD_CELLS.
        far_range (list): Liste des valeurs pour FAR.
        margin_range (list): Liste des valeurs pour THRESHOLD_MARGIN.

    Returns:
        dict: Meilleurs paramètres et accuracy correspondante.
    """
    best_accuracy = 0
    best_params = {}

    # Liste des combinaisons de paramètres
    param_combinations = list(product(ref_cells_range, guard_cells_range, far_range, margin_range))

    # Ajouter une barre de progression
    for ref_cells, guard_cells, far, margin in tqdm(param_combinations, desc="Grid Search Progress", unit="combination"):
        # Appliquer le modèle CA-CFAR avec les paramètres actuels
        data_cfar = ca_cfar(data.copy(), ref_cells=ref_cells, guard_cells=guard_cells, far=far, margin=margin)
        
        # Calculer l'accuracy
        correct_predictions = (data_cfar['anomaly_true'] == data_cfar['anomaly']).sum()
        total_predictions = len(data_cfar)
        accuracy = correct_predictions / total_predictions

        # Si l'accuracy est meilleure, sauvegarder les paramètres
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_params = {
                "REFERENCE_CELLS": ref_cells,
                "GUARD_CELLS": guard_cells,
                "FAR": far,
                "MARGIN": margin
            }

    return {"best_params": best_params, "best_accuracy": best_accuracy}

# %%
# Définir l'espace de recherche
ref_cells_range = range(10, 15, 10)  
guard_cells_range = range(1, 15)      
far_range = [0.001, 0.003, 0.005, 0.01]
margin_range = [round(x, 2) for x in np.arange(1.0, 2.0, 0.05)]

# Appliquer la recherche en grille
results = grid_search_cafar(data5, ref_cells_range, guard_cells_range, far_range, margin_range)

# Afficher les résultats
print("Meilleurs paramètres :")
print(results["best_params"])
print(f"Meilleure accuracy : {results['best_accuracy']:.4f}")
# Out:
# Grid Search Progress: 100%|██████████| 1120/1120 [00:10<00:00, 103.07combination/s]
# Meilleurs paramètres :
# {'REFERENCE_CELLS': 10, 'GUARD_CELLS': 14, 'FAR': 0.005, 'MARGIN': 1.45}
# Meilleure accuracy : 0.9896

# %%
# Rename keys to match the function's parameters
adjusted_params = {
    'ref_cells': results['best_params']['REFERENCE_CELLS'],
    'guard_cells': results['best_params']['GUARD_CELLS'],
    'far': results['best_params']['FAR'],
    'margin': results['best_params']['MARGIN'],
}

# Apply the CA-CFAR model with the adjusted parameters
data5_cfar_best = ca_cfar(data5.copy(), **adjusted_params)

# Visualize the results
visualize_cfar_results(data5_cfar_best, title="CA-CFAR Anomaly Detection Results (Best Parameters)")

# %%
def objective(trial):
    ref_cells = trial.suggest_int("ref_cells", 0, 100)
    guard_cells = trial.suggest_int("guard_cells", 0, 100)
    far = trial.suggest_float("far", 0.0005, 0.01)
    margin = trial.suggest_float("margin", 1.0, 2.0)
    
    data_cfar = ca_cfar(data5.copy(), ref_cells=ref_cells, guard_cells=guard_cells, far=far, margin=margin)
    correct_predictions = (data_cfar['anomaly_true'] == data_cfar['anomaly']).sum()
    total_predictions = len(data_cfar)
    return correct_predictions / total_predictions

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=300)

print("Meilleurs paramètres :", study.best_params)
print(f"Meilleure accuracy : {study.best_value:.5f}")
# Out:
# [I 2025-03-03 22:32:46,406] A new study created in memory with name: no-name-28e22ce5-1afc-41d7-8f57-37381ce53fbd
# [I 2025-03-03 22:32:46,437] Trial 0 finished with value: 0.575 and parameters: {'ref_cells': 66, 'guard_cells': 37, 'far': 0.003744056909040859, 'margin': 1.0232606817511538}. Best is trial 0 with value: 0.575.
# [I 2025-03-03 22:32:46,472] Trial 1 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 35, 'guard_cells': 47, 'far': 0.004462591410710941, 'margin': 1.4740881124424774}. Best is trial 1 with value: 0.9902777777777778.
# [I 2025-03-03 22:32:46,491] Trial 2 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 4, 'guard_cells': 88, 'far': 0.003676439618630518, 'margin': 1.9031675786627362}. Best is trial 1 with value: 0.9902777777777778.
# [I 2025-03-03 22:32:46,502] Trial 3 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 11, 'guard_cells': 83, 'far': 0.0050188267313081274, 'margin': 1.4933497933319444}. Best is trial 1 with value: 0.9902777777777778.
# [I 2025-03-03 22:32:46,522] Trial 4 finished with value: 0.6923611111111111 and parameters: {'ref_cells': 9, 'guard_cells': 44, 'far': 0.0006502253009816651, 'margin': 1.1073403689702}. Best is trial 1 with value: 0.9902777777777778.
# [I 2025-03-03 22:32:46,539] Trial 5 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 91, 'guard_cells': 18, 'far': 0.0008209738759559393, 'margin': 1.4611666114833528}. Best is trial 5 with value: 0.9909722222222223.
# [I 2025-03-03 22:32:46,550] Trial 6 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 41, 'guard_cells': 68, 'far': 0.0025836833557314623, 'margin': 1.9282410399576653}. Best is trial 5 with value: 0.9909722222222223.
# [I 2025-03-03 22:32:46,564] Trial 7 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 64, 'guard_cells': 16, 'far': 0.002617516947350741, 'margin': 1.4315204833017856}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,576] Trial 8 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 90, 'guard_cells': 16, 'far': 0.009616694318967842, 'margin': 1.5982359628960507}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,588] Trial 9 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 54, 'guard_cells': 59, 'far': 0.008973118396291105, 'margin': 1.350213662125709}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,613] Trial 10 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 69, 'guard_cells': 1, 'far': 0.0071487917851872276, 'margin': 1.6966162947024395}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,633] Trial 11 finished with value: 0.84375 and parameters: {'ref_cells': 98, 'guard_cells': 22, 'far': 0.0006907996238419874, 'margin': 1.243850569822302}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,657] Trial 12 finished with value: 0.9145833333333333 and parameters: {'ref_cells': 80, 'guard_cells': 1, 'far': 0.0021301496490067316, 'margin': 1.3003759970637492}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,678] Trial 13 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 80, 'guard_cells': 28, 'far': 0.00209267430722381, 'margin': 1.7171692642827288}. Best is trial 7 with value: 0.9930555555555556.
# [I 2025-03-03 22:32:46,699] Trial 14 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 60, 'guard_cells': 12, 'far': 0.006217220565193211, 'margin': 1.397708344156672}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,721] Trial 15 finished with value: 0.8118055555555556 and parameters: {'ref_cells': 54, 'guard_cells': 9, 'far': 0.006348353391781237, 'margin': 1.2060874775583483}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,742] Trial 16 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 27, 'guard_cells': 34, 'far': 0.006448922477644265, 'margin': 1.3885045783119032}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,763] Trial 17 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 65, 'guard_cells': 99, 'far': 0.008032843177903022, 'margin': 1.5848121018792025}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,784] Trial 18 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 47, 'guard_cells': 10, 'far': 0.0059687441946175935, 'margin': 1.7787891529698334}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,806] Trial 19 finished with value: 0.7625 and parameters: {'ref_cells': 23, 'guard_cells': 64, 'far': 0.0031848858399061383, 'margin': 1.1673501746124426}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,829] Trial 20 finished with value: 0.9875 and parameters: {'ref_cells': 59, 'guard_cells': 26, 'far': 0.005100527387134645, 'margin': 1.3984835951395573}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,851] Trial 21 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 82, 'guard_cells': 14, 'far': 0.001575993674139303, 'margin': 1.5925449862564176}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,877] Trial 22 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 100, 'guard_cells': 20, 'far': 0.0014245260333164093, 'margin': 1.4499007697629904}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,902] Trial 23 finished with value: 0.9104166666666667 and parameters: {'ref_cells': 73, 'guard_cells': 34, 'far': 0.0077046698074750355, 'margin': 1.2874105732669552}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,924] Trial 24 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 99, 'guard_cells': 7, 'far': 0.0015728745810522128, 'margin': 1.5690328560188802}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,947] Trial 25 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 46, 'guard_cells': 26, 'far': 0.0032700171017728905, 'margin': 1.406380565900086}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,972] Trial 26 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 88, 'guard_cells': 41, 'far': 0.004369509363504597, 'margin': 1.5239208196516227}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:46,994] Trial 27 finished with value: 0.9520833333333333 and parameters: {'ref_cells': 61, 'guard_cells': 55, 'far': 0.0058010697898964, 'margin': 1.3205654274870346}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,017] Trial 28 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 75, 'guard_cells': 20, 'far': 0.002523760697661316, 'margin': 1.6793226562084171}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,041] Trial 29 finished with value: 0.5576388888888889 and parameters: {'ref_cells': 35, 'guard_cells': 34, 'far': 0.00427825623509797, 'margin': 1.0099784237652036}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,063] Trial 30 finished with value: 0.6666666666666666 and parameters: {'ref_cells': 67, 'guard_cells': 3, 'far': 0.0013835137056431867, 'margin': 1.1002165890498947}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,085] Trial 31 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 90, 'guard_cells': 14, 'far': 0.0010463996022492563, 'margin': 1.449933380448034}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,110] Trial 32 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 100, 'guard_cells': 13, 'far': 0.001488963415944834, 'margin': 1.4480387711547336}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,133] Trial 33 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 96, 'guard_cells': 10, 'far': 0.0030386202119869134, 'margin': 1.4263695654541804}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,160] Trial 34 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 84, 'guard_cells': 6, 'far': 0.003472728649554209, 'margin': 1.5280057010948176}. Best is trial 14 with value: 0.9944444444444445.
# [I 2025-03-03 22:32:47,182] Trial 35 finished with value: 0.9972222222222222 and parameters: {'ref_cells': 94, 'guard_cells': 23, 'far': 0.003998596601358814, 'margin': 1.3942846225625356}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,208] Trial 36 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 73, 'guard_cells': 28, 'far': 0.004092806982057189, 'margin': 1.371558369797401}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,233] Trial 37 finished with value: 0.8958333333333334 and parameters: {'ref_cells': 60, 'guard_cells': 39, 'far': 0.004695583826526555, 'margin': 1.2768003310264477}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,259] Trial 38 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 93, 'guard_cells': 76, 'far': 0.0029470870898953084, 'margin': 1.5011682768475214}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,287] Trial 39 finished with value: 0.96875 and parameters: {'ref_cells': 40, 'guard_cells': 48, 'far': 0.0037493517354342592, 'margin': 1.3435270497082579}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,311] Trial 40 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 54, 'guard_cells': 21, 'far': 0.005600541016622754, 'margin': 1.8576739242651168}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,340] Trial 41 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 94, 'guard_cells': 19, 'far': 0.0026434679928790564, 'margin': 1.4347369091055147}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,362] Trial 42 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 85, 'guard_cells': 11, 'far': 0.003851752017031062, 'margin': 1.4950462248076786}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,389] Trial 43 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 96, 'guard_cells': 24, 'far': 0.0021899904866527434, 'margin': 1.6476298110939407}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,416] Trial 44 finished with value: 0.8368055555555556 and parameters: {'ref_cells': 88, 'guard_cells': 5, 'far': 0.005047918427471657, 'margin': 1.2377097567774697}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,442] Trial 45 finished with value: 0.975 and parameters: {'ref_cells': 76, 'guard_cells': 17, 'far': 0.0028999524580164086, 'margin': 1.3538484948535976}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,472] Trial 46 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 94, 'guard_cells': 29, 'far': 0.004554646455432876, 'margin': 1.998220518265602}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,493] Trial 47 finished with value: 0.99375 and parameters: {'ref_cells': 79, 'guard_cells': 17, 'far': 0.006970968702751407, 'margin': 1.412668057403624}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,515] Trial 48 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 65, 'guard_cells': 9, 'far': 0.006920048316719045, 'margin': 1.5419383368354915}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,577] Trial 49 finished with value: 0.7638888888888888 and parameters: {'ref_cells': 79, 'guard_cells': 17, 'far': 0.007798769923453804, 'margin': 1.1704551824801035}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,601] Trial 50 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 69, 'guard_cells': 1, 'far': 0.008313467061127094, 'margin': 1.6353955557993272}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,626] Trial 51 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 87, 'guard_cells': 31, 'far': 0.0069764442689190295, 'margin': 1.4333023603032902}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,648] Trial 52 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 85, 'guard_cells': 24, 'far': 0.006738784352066367, 'margin': 1.4128329538231192}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,673] Trial 53 finished with value: 0.9541666666666667 and parameters: {'ref_cells': 78, 'guard_cells': 31, 'far': 0.0072876293079874544, 'margin': 1.3220852906299236}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,698] Trial 54 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 90, 'guard_cells': 13, 'far': 0.006305539570500004, 'margin': 1.4842564306076838}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,728] Trial 55 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 72, 'guard_cells': 53, 'far': 0.0073289905047609445, 'margin': 1.3885777709197427}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,752] Trial 56 finished with value: 0.9215277777777777 and parameters: {'ref_cells': 1, 'guard_cells': 53, 'far': 0.005396443532778121, 'margin': 1.3798103301227116}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,782] Trial 57 finished with value: 0.85625 and parameters: {'ref_cells': 72, 'guard_cells': 58, 'far': 0.009436167464398477, 'margin': 1.239722325528702}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,808] Trial 58 finished with value: 0.9083333333333333 and parameters: {'ref_cells': 57, 'guard_cells': 44, 'far': 0.00866724892465186, 'margin': 1.2844392776169435}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,830] Trial 59 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 62, 'guard_cells': 66, 'far': 0.007475450444178211, 'margin': 1.4781061168149785}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,853] Trial 60 finished with value: 0.9486111111111111 and parameters: {'ref_cells': 49, 'guard_cells': 72, 'far': 0.00656659656743071, 'margin': 1.3174084433570827}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,877] Trial 61 finished with value: 0.99375 and parameters: {'ref_cells': 81, 'guard_cells': 16, 'far': 0.00708713193028175, 'margin': 1.4101061386619214}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,902] Trial 62 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 70, 'guard_cells': 9, 'far': 0.005995913101347333, 'margin': 1.4053931182992618}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,929] Trial 63 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 70, 'guard_cells': 9, 'far': 0.006159074161206805, 'margin': 1.3992308247314011}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,952] Trial 64 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 67, 'guard_cells': 10, 'far': 0.006294223259911043, 'margin': 1.3745071009952112}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,975] Trial 65 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 57, 'guard_cells': 0, 'far': 0.0054571212661747555, 'margin': 1.559683754383426}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:47,996] Trial 66 finished with value: 0.9770833333333333 and parameters: {'ref_cells': 69, 'guard_cells': 5, 'far': 0.006046490495741993, 'margin': 1.3525921916165566}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,020] Trial 67 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 72, 'guard_cells': 8, 'far': 0.005929307900658408, 'margin': 1.4003252758764466}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,044] Trial 68 finished with value: 0.8763888888888889 and parameters: {'ref_cells': 75, 'guard_cells': 7, 'far': 0.004865721988305568, 'margin': 1.267030141541057}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,067] Trial 69 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 63, 'guard_cells': 8, 'far': 0.006031280706996263, 'margin': 1.4653848150218824}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,090] Trial 70 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 54, 'guard_cells': 13, 'far': 0.005655551529238046, 'margin': 1.5110117008214978}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,114] Trial 71 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 70, 'guard_cells': 3, 'far': 0.006604798627090077, 'margin': 1.403073017275297}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,138] Trial 72 finished with value: 0.9604166666666667 and parameters: {'ref_cells': 71, 'guard_cells': 3, 'far': 0.005946069988588229, 'margin': 1.3308598512910337}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,164] Trial 73 finished with value: 0.99375 and parameters: {'ref_cells': 69, 'guard_cells': 4, 'far': 0.00645719136834004, 'margin': 1.3869494216143443}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,190] Trial 74 finished with value: 0.9875 and parameters: {'ref_cells': 15, 'guard_cells': 12, 'far': 0.005246431924352559, 'margin': 1.467154406302844}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,216] Trial 75 finished with value: 0.9736111111111111 and parameters: {'ref_cells': 58, 'guard_cells': 93, 'far': 0.006765063607558606, 'margin': 1.3653659335984902}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,244] Trial 76 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 76, 'guard_cells': 0, 'far': 0.007401563127205888, 'margin': 1.415863536896241}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,290] Trial 77 finished with value: 0.9270833333333334 and parameters: {'ref_cells': 65, 'guard_cells': 9, 'far': 0.006271327118395586, 'margin': 1.3027540917394154}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,319] Trial 78 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 83, 'guard_cells': 52, 'far': 0.005710821556582429, 'margin': 1.432790760252264}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,352] Trial 79 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 83, 'guard_cells': 51, 'far': 0.004080922099066478, 'margin': 1.4562044894903934}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,376] Trial 80 finished with value: 0.99375 and parameters: {'ref_cells': 97, 'guard_cells': 49, 'far': 0.004806138659121028, 'margin': 1.4352522996028352}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,399] Trial 81 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 71, 'guard_cells': 58, 'far': 0.005832217502040485, 'margin': 1.3925835982702122}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,426] Trial 82 finished with value: 0.9611111111111111 and parameters: {'ref_cells': 77, 'guard_cells': 61, 'far': 0.0066318233359289065, 'margin': 1.3369223482808146}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,452] Trial 83 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 92, 'guard_cells': 45, 'far': 0.0061215162818573955, 'margin': 1.500881164833903}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,479] Trial 84 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 74, 'guard_cells': 15, 'far': 0.005668687376870856, 'margin': 1.3624370757571789}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,501] Trial 85 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 87, 'guard_cells': 6, 'far': 0.005154563013640827, 'margin': 1.428860483255324}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,528] Trial 86 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 82, 'guard_cells': 11, 'far': 0.007721094128200763, 'margin': 1.5407958295118487}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,553] Trial 87 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 96, 'guard_cells': 3, 'far': 0.0033787688491956234, 'margin': 1.3947777792396197}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,580] Trial 88 finished with value: 0.9256944444444445 and parameters: {'ref_cells': 96, 'guard_cells': 40, 'far': 0.003485989008911992, 'margin': 1.3050812550962434}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,606] Trial 89 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 99, 'guard_cells': 19, 'far': 0.003174874251546465, 'margin': 1.4702206603325088}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,630] Trial 90 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 94, 'guard_cells': 54, 'far': 0.0028193427724575145, 'margin': 1.447588877430687}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,655] Trial 91 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 89, 'guard_cells': 3, 'far': 0.005379288938577524, 'margin': 1.4012395285919383}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,679] Trial 92 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 89, 'guard_cells': 2, 'far': 0.00395557806125617, 'margin': 1.3861550443006365}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,703] Trial 93 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 89, 'guard_cells': 2, 'far': 0.0039703780245437985, 'margin': 1.3523735500129452}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,727] Trial 94 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 95, 'guard_cells': 3, 'far': 0.004275671650639201, 'margin': 1.3810687046202954}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,751] Trial 95 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 87, 'guard_cells': 4, 'far': 0.002323144194610913, 'margin': 1.418881360242765}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,776] Trial 96 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 92, 'guard_cells': 4, 'far': 0.002320269254541361, 'margin': 1.4234174254411993}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,799] Trial 97 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 91, 'guard_cells': 5, 'far': 0.0019329384097712444, 'margin': 1.5209743799477875}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,824] Trial 98 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 86, 'guard_cells': 0, 'far': 0.004543103554920453, 'margin': 1.4906441809595186}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,848] Trial 99 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 92, 'guard_cells': 3, 'far': 0.0024694367722709358, 'margin': 1.425323445938443}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,875] Trial 100 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 90, 'guard_cells': 3, 'far': 0.0022435359510480967, 'margin': 1.436413311700578}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,898] Trial 101 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 91, 'guard_cells': 3, 'far': 0.002361343046407723, 'margin': 1.4351340803360582}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,927] Trial 102 finished with value: 0.99375 and parameters: {'ref_cells': 89, 'guard_cells': 6, 'far': 0.0020881446503560816, 'margin': 1.418130828927862}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,950] Trial 103 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 84, 'guard_cells': 1, 'far': 0.002695549246271588, 'margin': 1.4488597021227514}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,976] Trial 104 finished with value: 0.9666666666666667 and parameters: {'ref_cells': 92, 'guard_cells': 4, 'far': 0.002400485649973699, 'margin': 1.3443512480860877}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:48,998] Trial 105 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 98, 'guard_cells': 7, 'far': 0.0017491678805895698, 'margin': 1.4028021103000692}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,050] Trial 106 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 100, 'guard_cells': 6, 'far': 0.00347846868016407, 'margin': 1.3740333486507006}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,075] Trial 107 finished with value: 0.94375 and parameters: {'ref_cells': 97, 'guard_cells': 7, 'far': 0.0013731682912705005, 'margin': 1.3259393317095436}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,099] Trial 108 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 93, 'guard_cells': 11, 'far': 0.001902271786933195, 'margin': 1.4739753513205076}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,125] Trial 109 finished with value: 0.5909722222222222 and parameters: {'ref_cells': 87, 'guard_cells': 2, 'far': 0.0010931476579239313, 'margin': 1.043093366514094}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,150] Trial 110 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 85, 'guard_cells': 0, 'far': 0.0018351928281725271, 'margin': 1.404556414741284}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,180] Trial 111 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 89, 'guard_cells': 4, 'far': 0.0016828166954785998, 'margin': 1.4340713062891344}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,210] Trial 112 finished with value: 0.98125 and parameters: {'ref_cells': 98, 'guard_cells': 8, 'far': 0.002411056866606032, 'margin': 1.3632988577708878}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,238] Trial 113 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 95, 'guard_cells': 2, 'far': 0.002230131418880262, 'margin': 1.4560320074692992}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,263] Trial 114 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 93, 'guard_cells': 14, 'far': 0.0005022160149399267, 'margin': 1.4189935529189526}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,288] Trial 115 finished with value: 0.99375 and parameters: {'ref_cells': 81, 'guard_cells': 14, 'far': 0.0012008889972875323, 'margin': 1.396658159838373}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,316] Trial 116 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 94, 'guard_cells': 10, 'far': 0.0005850111226279377, 'margin': 1.4158458409916606}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,343] Trial 117 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 94, 'guard_cells': 10, 'far': 0.000781447322512384, 'margin': 1.3782191072772014}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,367] Trial 118 finished with value: 0.8680555555555556 and parameters: {'ref_cells': 98, 'guard_cells': 15, 'far': 0.0005775151703159608, 'margin': 1.2644317935807714}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,393] Trial 119 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 100, 'guard_cells': 12, 'far': 0.0008902539914999283, 'margin': 1.491471307380239}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,417] Trial 120 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 88, 'guard_cells': 8, 'far': 0.0036599367305577076, 'margin': 1.4105209520744342}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,443] Trial 121 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 92, 'guard_cells': 5, 'far': 0.0031075885989837564, 'margin': 1.4183015882076833}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,472] Trial 122 finished with value: 0.9659722222222222 and parameters: {'ref_cells': 96, 'guard_cells': 23, 'far': 0.005393491556706149, 'margin': 1.3396979333358887}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,498] Trial 123 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 83, 'guard_cells': 7, 'far': 0.0005480027616730507, 'margin': 1.3893318886198411}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,526] Trial 124 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 93, 'guard_cells': 5, 'far': 0.0012880340276889733, 'margin': 1.456707921400555}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,553] Trial 125 finished with value: 0.9819444444444444 and parameters: {'ref_cells': 86, 'guard_cells': 10, 'far': 0.0026384389439801734, 'margin': 1.3615925092645376}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,582] Trial 126 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 91, 'guard_cells': 0, 'far': 0.001583079343066719, 'margin': 1.7721435498367857}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,615] Trial 127 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 97, 'guard_cells': 12, 'far': 0.0009373794978234889, 'margin': 1.4223183492255211}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,644] Trial 128 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 97, 'guard_cells': 21, 'far': 0.0010147650873644795, 'margin': 1.4735111816400606}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,670] Trial 129 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 95, 'guard_cells': 18, 'far': 0.0008731927337456776, 'margin': 1.399908044444811}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,697] Trial 130 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 99, 'guard_cells': 13, 'far': 0.0005080417222997803, 'margin': 1.44898709139714}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,725] Trial 131 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 93, 'guard_cells': 9, 'far': 0.0007320821065089167, 'margin': 1.4094277405399687}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,750] Trial 132 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 90, 'guard_cells': 7, 'far': 0.002871632810253066, 'margin': 1.4259472029827436}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,784] Trial 133 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 88, 'guard_cells': 2, 'far': 0.0016638236930198577, 'margin': 1.3790275329127868}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,813] Trial 134 finished with value: 0.99375 and parameters: {'ref_cells': 97, 'guard_cells': 81, 'far': 0.005018659028539366, 'margin': 1.4228469666648247}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,844] Trial 135 finished with value: 0.9256944444444445 and parameters: {'ref_cells': 95, 'guard_cells': 4, 'far': 0.0010720591661984536, 'margin': 1.3115885110794991}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,870] Trial 136 finished with value: 0.9701388888888889 and parameters: {'ref_cells': 91, 'guard_cells': 11, 'far': 0.003262925970053157, 'margin': 1.3496207877241775}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,899] Trial 137 finished with value: 0.9875 and parameters: {'ref_cells': 85, 'guard_cells': 46, 'far': 0.005570852018546935, 'margin': 1.508875731814153}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,927] Trial 138 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 79, 'guard_cells': 36, 'far': 0.0020068958729848136, 'margin': 1.4800481673561876}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,952] Trial 139 finished with value: 0.9875 and parameters: {'ref_cells': 43, 'guard_cells': 16, 'far': 0.0017491541661411542, 'margin': 1.3876697491944987}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:49,978] Trial 140 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 93, 'guard_cells': 6, 'far': 0.003828420185619366, 'margin': 1.4433863601555987}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,005] Trial 141 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 90, 'guard_cells': 3, 'far': 0.0024984700136187195, 'margin': 1.4289586311376934}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,032] Trial 142 finished with value: 0.9777777777777777 and parameters: {'ref_cells': 30, 'guard_cells': 2, 'far': 0.0023231985256910994, 'margin': 1.3681794455690492}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,060] Trial 143 finished with value: 0.99375 and parameters: {'ref_cells': 87, 'guard_cells': 8, 'far': 0.002081353921038469, 'margin': 1.405988028447212}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,085] Trial 144 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 89, 'guard_cells': 51, 'far': 0.0013871225330639296, 'margin': 1.4642463835598867}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,114] Trial 145 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 100, 'guard_cells': 4, 'far': 0.004149302138632858, 'margin': 1.4296636421269129}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,140] Trial 146 finished with value: 0.99375 and parameters: {'ref_cells': 95, 'guard_cells': 6, 'far': 0.003600504832342309, 'margin': 1.4486945303626884}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,168] Trial 147 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 92, 'guard_cells': 0, 'far': 0.0026447995448334875, 'margin': 1.3867362911056313}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,195] Trial 148 finished with value: 0.9506944444444444 and parameters: {'ref_cells': 98, 'guard_cells': 9, 'far': 0.002164228162445739, 'margin': 1.3290901162127717}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,222] Trial 149 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 90, 'guard_cells': 12, 'far': 0.005766764653563691, 'margin': 1.4124362225857108}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,251] Trial 150 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 84, 'guard_cells': 2, 'far': 0.0033623705301271153, 'margin': 1.3580124202953439}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,282] Trial 151 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 93, 'guard_cells': 4, 'far': 0.002951042115763286, 'margin': 1.4371660319599782}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,309] Trial 152 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 87, 'guard_cells': 3, 'far': 0.0023649495184674863, 'margin': 1.4332865342969447}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,339] Trial 153 finished with value: 0.99375 and parameters: {'ref_cells': 91, 'guard_cells': 5, 'far': 0.002715465893108505, 'margin': 1.3939446790548042}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,365] Trial 154 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 89, 'guard_cells': 0, 'far': 0.0007882197987267472, 'margin': 1.4932334628346728}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,392] Trial 155 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 7, 'far': 0.002250544562563629, 'margin': 1.4137351191342789}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,417] Trial 156 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 97, 'guard_cells': 8, 'far': 0.0019339590271196844, 'margin': 1.3696125808315212}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,445] Trial 157 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 95, 'guard_cells': 14, 'far': 0.005314762507599193, 'margin': 1.4642174378423911}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,487] Trial 158 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 94, 'guard_cells': 10, 'far': 0.004690167917968663, 'margin': 1.4213902654454658}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,516] Trial 159 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 98, 'guard_cells': 6, 'far': 0.0012188981581565373, 'margin': 1.3982083853715301}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,541] Trial 160 finished with value: 0.9701388888888889 and parameters: {'ref_cells': 52, 'guard_cells': 43, 'far': 0.0014792741356325157, 'margin': 1.3486327855091098}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,566] Trial 161 finished with value: 0.99375 and parameters: {'ref_cells': 92, 'guard_cells': 2, 'far': 0.002520291347533987, 'margin': 1.4436944639729237}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,596] Trial 162 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 90, 'guard_cells': 4, 'far': 0.0022986779937358504, 'margin': 1.414697188735613}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,622] Trial 163 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 95, 'guard_cells': 56, 'far': 0.002218458685712833, 'margin': 1.380659280277022}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,651] Trial 164 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 82, 'guard_cells': 7, 'far': 0.003045826755562478, 'margin': 1.4586351749889435}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,678] Trial 165 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 92, 'guard_cells': 2, 'far': 0.0017923303692340986, 'margin': 1.4030777431015293}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,704] Trial 166 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 96, 'guard_cells': 0, 'far': 0.0017216849477709687, 'margin': 1.4003279478928594}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,728] Trial 167 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 100, 'guard_cells': 0, 'far': 0.001690365692318566, 'margin': 1.3953303705128284}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,754] Trial 168 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 96, 'guard_cells': 11, 'far': 0.0018473446522659844, 'margin': 1.3712429169080858}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,780] Trial 169 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 97, 'guard_cells': 6, 'far': 0.0009878755310943738, 'margin': 1.4065766770367334}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,805] Trial 170 finished with value: 0.9583333333333334 and parameters: {'ref_cells': 93, 'guard_cells': 2, 'far': 0.0006490730064443097, 'margin': 1.3379083306312576}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,829] Trial 171 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 88, 'guard_cells': 4, 'far': 0.002044440721958809, 'margin': 1.4213005945324548}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,857] Trial 172 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 87, 'guard_cells': 5, 'far': 0.0020652181959389245, 'margin': 1.4134826060122654}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,888] Trial 173 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 94, 'guard_cells': 8, 'far': 0.001533298066331264, 'margin': 1.394710246156386}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,931] Trial 174 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 92, 'guard_cells': 1, 'far': 0.0018980088677841953, 'margin': 1.3745586660076505}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:50,989] Trial 175 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 98, 'guard_cells': 4, 'far': 0.00495305473964155, 'margin': 1.478299491341363}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,027] Trial 176 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 85, 'guard_cells': 9, 'far': 0.006511476984456974, 'margin': 1.4267395036128923}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,058] Trial 177 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 95, 'guard_cells': 0, 'far': 0.0011804938443878733, 'margin': 1.4170056566478484}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,093] Trial 178 finished with value: 0.98125 and parameters: {'ref_cells': 96, 'guard_cells': 0, 'far': 0.0012352494580048588, 'margin': 1.3628484850579419}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,125] Trial 179 finished with value: 0.99375 and parameters: {'ref_cells': 100, 'guard_cells': 6, 'far': 0.0009388922900794626, 'margin': 1.44697284636676}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,160] Trial 180 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 88, 'guard_cells': 2, 'far': 0.004427720378123694, 'margin': 1.3904217872206626}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,195] Trial 181 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 89, 'guard_cells': 2, 'far': 0.004459369556599063, 'margin': 1.389747701120215}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,230] Trial 182 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 89, 'guard_cells': 2, 'far': 0.0047051574826547345, 'margin': 1.390055150755602}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,264] Trial 183 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 88, 'guard_cells': 2, 'far': 0.004394685571772281, 'margin': 1.3988781120264837}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,298] Trial 184 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 85, 'guard_cells': 0, 'far': 0.004656130340659925, 'margin': 1.3853827281982358}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,337] Trial 185 finished with value: 0.9770833333333333 and parameters: {'ref_cells': 94, 'guard_cells': 4, 'far': 0.00435041773452383, 'margin': 1.351659697259957}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,374] Trial 186 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 88, 'guard_cells': 26, 'far': 0.0041864705541139234, 'margin': 1.410462140442876}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,408] Trial 187 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 83, 'guard_cells': 7, 'far': 0.00449009009183309, 'margin': 1.3730992099019392}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,443] Trial 188 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 91, 'guard_cells': 2, 'far': 0.005053735214641368, 'margin': 1.4064073212958699}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,482] Trial 189 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 96, 'guard_cells': 12, 'far': 0.0048217532173749035, 'margin': 1.4333829343886306}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,519] Trial 190 finished with value: 0.9451388888888889 and parameters: {'ref_cells': 87, 'guard_cells': 0, 'far': 0.0005041131225822233, 'margin': 1.3267153689656288}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,550] Trial 191 finished with value: 0.99375 and parameters: {'ref_cells': 90, 'guard_cells': 2, 'far': 0.0040469754419658974, 'margin': 1.3838648986143025}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,584] Trial 192 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 89, 'guard_cells': 5, 'far': 0.0039061725123175663, 'margin': 1.3934396128422628}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,620] Trial 193 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 93, 'guard_cells': 3, 'far': 0.005473060043384201, 'margin': 1.3613024487138186}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,653] Trial 194 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 80, 'guard_cells': 6, 'far': 0.0007202145881363369, 'margin': 1.4177417456530936}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,689] Trial 195 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 86, 'guard_cells': 9, 'far': 0.004280079981366045, 'margin': 1.4449953888436187}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,719] Trial 196 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 98, 'guard_cells': 0, 'far': 0.0052288859848985195, 'margin': 1.3889718552048047}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,757] Trial 197 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 95, 'guard_cells': 4, 'far': 0.005823831942959046, 'margin': 1.4105263096820242}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,790] Trial 198 finished with value: 0.9666666666666667 and parameters: {'ref_cells': 91, 'guard_cells': 2, 'far': 0.0014002132547734406, 'margin': 1.3476162752516099}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,822] Trial 199 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 89, 'guard_cells': 7, 'far': 0.004583429376142519, 'margin': 1.459863876002898}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:51,852] Trial 200 finished with value: 0.98125 and parameters: {'ref_cells': 9, 'guard_cells': 10, 'far': 0.0011874786012501118, 'margin': 1.4237622098963074}. Best is trial 35 with value: 0.9972222222222222.
# ...
# [I 2025-03-03 22:32:52,948] Trial 234 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 4, 'far': 0.003967895446851534, 'margin': 1.3957546750358487}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:52,977] Trial 235 finished with value: 0.9875 and parameters: {'ref_cells': 98, 'guard_cells': 2, 'far': 0.0015695316819621884, 'margin': 1.3691755425543495}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,006] Trial 236 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 100, 'guard_cells': 7, 'far': 0.0036786739297374076, 'margin': 1.4202182299261565}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,036] Trial 237 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 94, 'guard_cells': 0, 'far': 0.004552986011570265, 'margin': 1.9398534479260912}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,069] Trial 238 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 96, 'guard_cells': 5, 'far': 0.0010035888745099386, 'margin': 1.4004106496831477}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,098] Trial 239 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 92, 'guard_cells': 2, 'far': 0.0041997711498350234, 'margin': 1.4383127452901199}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,132] Trial 240 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 98, 'guard_cells': 7, 'far': 0.002050406702606227, 'margin': 1.3801133245633852}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,167] Trial 241 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 100, 'guard_cells': 0, 'far': 0.003377532973239207, 'margin': 1.4126852851388851}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,197] Trial 242 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 97, 'guard_cells': 0, 'far': 0.0033537674409095156, 'margin': 1.4125194643358339}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,233] Trial 243 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 2, 'far': 0.000588904237595494, 'margin': 1.4224360312968867}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,265] Trial 244 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 67, 'guard_cells': 3, 'far': 0.0033062272050630686, 'margin': 1.411520716329639}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,294] Trial 245 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 67, 'guard_cells': 4, 'far': 0.0034110274244107284, 'margin': 1.4505922569214864}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,327] Trial 246 finished with value: 0.99375 and parameters: {'ref_cells': 73, 'guard_cells': 3, 'far': 0.003310844964742381, 'margin': 1.431549353533534}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,356] Trial 247 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 68, 'guard_cells': 9, 'far': 0.009902238489869684, 'margin': 1.3873951534656612}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,387] Trial 248 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 61, 'guard_cells': 6, 'far': 0.003504609387315168, 'margin': 1.3521476105608252}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,417] Trial 249 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 94, 'guard_cells': 4, 'far': 0.0032731444428982666, 'margin': 1.416013723237051}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,447] Trial 250 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 70, 'guard_cells': 5, 'far': 0.0030010251561632868, 'margin': 1.4195589679973868}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,477] Trial 251 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 93, 'guard_cells': 8, 'far': 0.0033542646533980787, 'margin': 1.465495365741288}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,506] Trial 252 finished with value: 0.99375 and parameters: {'ref_cells': 91, 'guard_cells': 3, 'far': 0.0032217317606259765, 'margin': 1.4436276111154625}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,534] Trial 253 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 64, 'guard_cells': 6, 'far': 0.0031456524392387314, 'margin': 1.3874998570472568}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,566] Trial 254 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 49, 'guard_cells': 11, 'far': 0.0016284611603402165, 'margin': 1.4241647921819394}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,594] Trial 255 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 94, 'guard_cells': 4, 'far': 0.0017912760489195334, 'margin': 1.3751132860751227}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,622] Trial 256 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 38, 'guard_cells': 2, 'far': 0.0007989231960179735, 'margin': 1.407716076415438}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,655] Trial 257 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 45, 'guard_cells': 9, 'far': 0.0037275798960674134, 'margin': 1.4389264097101648}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,701] Trial 258 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 95, 'guard_cells': 15, 'far': 0.0019241630658930425, 'margin': 1.3602000175856113}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,734] Trial 259 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 92, 'guard_cells': 95, 'far': 0.0028403328506403478, 'margin': 1.3953254893485856}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,765] Trial 260 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 96, 'guard_cells': 6, 'far': 0.0032134409715293324, 'margin': 1.4147497484424776}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,799] Trial 261 finished with value: 0.99375 and parameters: {'ref_cells': 94, 'guard_cells': 4, 'far': 0.0035837591851380006, 'margin': 1.4539959628899786}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,832] Trial 262 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 75, 'guard_cells': 2, 'far': 0.001405537488914936, 'margin': 1.3819186308620246}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,864] Trial 263 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 91, 'guard_cells': 12, 'far': 0.0005084775289410855, 'margin': 1.4794269685911559}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,897] Trial 264 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 32, 'far': 0.0021593807737334126, 'margin': 1.4277358004624943}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,930] Trial 265 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 93, 'guard_cells': 2, 'far': 0.004884184351285429, 'margin': 1.399458268225606}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,965] Trial 266 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 97, 'guard_cells': 8, 'far': 0.007112323495590419, 'margin': 1.360150555696065}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:53,995] Trial 267 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 89, 'guard_cells': 5, 'far': 0.0008873001805930992, 'margin': 1.4149472197553843}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,029] Trial 268 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 57, 'guard_cells': 0, 'far': 0.0011120864553993122, 'margin': 1.4347923510760892}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,065] Trial 269 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 100, 'guard_cells': 4, 'far': 0.003359755276011081, 'margin': 1.3827567349614678}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,100] Trial 270 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 95, 'guard_cells': 7, 'far': 0.004145393879642768, 'margin': 1.6193575675700542}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,131] Trial 271 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 91, 'guard_cells': 2, 'far': 0.003868036552667636, 'margin': 1.4591203882472454}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,163] Trial 272 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 98, 'guard_cells': 10, 'far': 0.004755282191044025, 'margin': 1.4029865108670307}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,193] Trial 273 finished with value: 0.9645833333333333 and parameters: {'ref_cells': 98, 'guard_cells': 11, 'far': 0.004809734729812545, 'margin': 1.3396572264333018}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,226] Trial 274 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 98, 'guard_cells': 13, 'far': 0.004664112833011541, 'margin': 1.4186876530265424}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,255] Trial 275 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 14, 'guard_cells': 17, 'far': 0.005173077638654778, 'margin': 1.3730918547804114}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,284] Trial 276 finished with value: 0.99375 and parameters: {'ref_cells': 100, 'guard_cells': 9, 'far': 0.0007169964249131408, 'margin': 1.4394354768875184}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,315] Trial 277 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 23, 'guard_cells': 10, 'far': 0.0019254785051820624, 'margin': 1.3947297437232329}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,345] Trial 278 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 93, 'guard_cells': 6, 'far': 0.006287486412502554, 'margin': 1.4109266461349672}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,374] Trial 279 finished with value: 0.9951388888888889 and parameters: {'ref_cells': 77, 'guard_cells': 4, 'far': 0.00305506950770689, 'margin': 1.427931027489414}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,402] Trial 280 finished with value: 0.99375 and parameters: {'ref_cells': 97, 'guard_cells': 8, 'far': 0.004633315845944055, 'margin': 1.3863439068094536}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,435] Trial 281 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 90, 'guard_cells': 14, 'far': 0.0016192703872814997, 'margin': 1.4605901119824123}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,464] Trial 282 finished with value: 0.98125 and parameters: {'ref_cells': 87, 'guard_cells': 1, 'far': 0.0021315776848858663, 'margin': 1.3662364211595257}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,517] Trial 283 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 7, 'far': 0.0049496277156125005, 'margin': 1.401389745189202}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,546] Trial 284 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 100, 'guard_cells': 0, 'far': 0.0012969096441591407, 'margin': 1.4450361664509557}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,578] Trial 285 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 93, 'guard_cells': 5, 'far': 0.0025471396009063107, 'margin': 1.4204414898322433}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,614] Trial 286 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 66, 'guard_cells': 3, 'far': 0.0034592455418813615, 'margin': 1.3873294088278043}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,646] Trial 287 finished with value: 0.9965277777777778 and parameters: {'ref_cells': 98, 'guard_cells': 10, 'far': 0.0043695885881962675, 'margin': 1.4074166308116445}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,679] Trial 288 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 98, 'guard_cells': 11, 'far': 0.004456104445254595, 'margin': 1.4838433193412652}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,712] Trial 289 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 97, 'guard_cells': 12, 'far': 0.004305352929773421, 'margin': 1.4298402049858103}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,747] Trial 290 finished with value: 0.6576388888888889 and parameters: {'ref_cells': 95, 'guard_cells': 10, 'far': 0.0009343293474514459, 'margin': 1.098644758345497}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,782] Trial 291 finished with value: 0.9923611111111111 and parameters: {'ref_cells': 72, 'guard_cells': 19, 'far': 0.0017314323935565925, 'margin': 1.4080382121036825}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,816] Trial 292 finished with value: 0.9736111111111111 and parameters: {'ref_cells': 100, 'guard_cells': 15, 'far': 0.004084627107707216, 'margin': 1.3508978021179963}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,848] Trial 293 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 98, 'guard_cells': 8, 'far': 0.006585277856979544, 'margin': 1.4488813151715312}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,880] Trial 294 finished with value: 0.9958333333333333 and parameters: {'ref_cells': 95, 'guard_cells': 6, 'far': 0.003687169417321325, 'margin': 1.4131801378029352}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,912] Trial 295 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 98, 'guard_cells': 9, 'far': 0.0006460199658126056, 'margin': 1.431143417899786}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,945] Trial 296 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 94, 'guard_cells': 13, 'far': 0.0020587836034463955, 'margin': 1.7332048216959164}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:54,979] Trial 297 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 77, 'far': 0.00318643173268349, 'margin': 1.374571141563239}. Best is trial 35 with value: 0.9972222222222222.
# [I 2025-03-03 22:32:55,012] Trial 298 finished with value: 0.9979166666666667 and parameters: {'ref_cells': 100, 'guard_cells': 38, 'far': 0.004260663498173623, 'margin': 1.4073432099780447}. Best is trial 298 with value: 0.9979166666666667.
# [I 2025-03-03 22:32:55,045] Trial 299 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 100, 'guard_cells': 41, 'far': 0.0042213355223655715, 'margin': 1.4552609224210729}. Best is trial 298 with value: 0.9979166666666667.
# Meilleurs paramètres : {'ref_cells': 100, 'guard_cells': 38, 'far': 0.004260663498173623, 'margin': 1.4073432099780447}
# Meilleure accuracy : 0.99792

# %%
# Apply the CA-CFAR model with the best parameters with Optuna
data5_cfar_optuna = ca_cfar(data5.copy(), **study.best_params)

# Visualize the results
visualize_cfar_results(data5_cfar_optuna, title="CA-CFAR Anomaly Detection Results (Optuna)")

# %% [markdown]
# # Generation

# %%
def generate_synthetic_data(output_path, num_anomalies=10, num_minutes=1440, kpi_range=(0.3, 0.7), anomaly_range=(0.701, 0.75)):
    """
    Génère un jeu de données synthétique avec anomalies et l'enregistre dans un fichier CSV.

    Parameters:
        output_path (str): Chemin où le fichier CSV sera sauvegardé.
        num_anomalies (int): Nombre d'anomalies à inclure dans les données.
        num_minutes (int): Nombre total de points de données (minutes).
        kpi_range (tuple): Intervalle des valeurs normales du KPI.
        anomaly_range (tuple): Intervalle des valeurs d'anomalies.
    """
    # Génération des timestamps
    time_steps = pd.date_range(start='2024-01-01', periods=num_minutes, freq='min')
    
    # Génération des valeurs normales du KPI
    kpi_values = np.random.uniform(kpi_range[0], kpi_range[1], size=len(time_steps))
    
    # Introduire des anomalies
    anomaly_indices = random.sample(range(len(kpi_values)), num_anomalies)
    kpi_values[anomaly_indices] = np.random.uniform(anomaly_range[0], anomaly_range[1], size=num_anomalies)
    
    # Création du DataFrame
    data = pd.DataFrame({
        'timestamp': time_steps,
        'kpi': kpi_values,
        'anomaly_true': [1 if i in anomaly_indices else 0 for i in range(len(time_steps))]
    })
    
    # Enregistrement dans un fichier CSV
    data.to_csv(output_path, index=False)
    print(f"Données synthétiques générées et sauvegardées dans : {output_path}")

# Exemple d'utilisation
generate_synthetic_data('../data/generated_data.csv', num_anomalies=100)
# Out:
# Données synthétiques générées et sauvegardées dans : ../data/generated_data.csv

# %%
# Load the generated data and plot 
generated_data = pd.read_csv('../data/generated_data.csv')
plot_time_series(generated_data, title="Generated Time-Series Data", show_anom=True)

# %%
# Search for the best parameters using Optuna
def optuna_search(data, n_trials=300):
    """
    Search for the best parameters using Optuna.

    Parameters:
        data (DataFrame): The dataset containing 'kpi' and 'anomaly_true' columns.
        n_trials (int): Number of trials for the optimization.

    Returns:
        dict: Best parameters and best accuracy.
    """
    def objective(trial):
        ref_cells = trial.suggest_int("ref_cells", 0, 100)
        guard_cells = trial.suggest_int("guard_cells", 0, 100)
        far = trial.suggest_float("far", 0.0005, 0.01)
        margin = trial.suggest_float("margin", 1.0, 2.0)
        
        data_cfar = ca_cfar(data.copy(), ref_cells=ref_cells, guard_cells=guard_cells, far=far, margin=margin)
        correct_predictions = (data_cfar['anomaly_true'] == data_cfar['anomaly']).sum()
        total_predictions = len(data_cfar)
        return correct_predictions / total_predictions

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials, callbacks=[lambda study, trial: study.stop() if study.best_value == 1.0 else None])

    return {"best_params": study.best_params, "best_accuracy": study.best_value}

# %%
# Example usage
results = optuna_search(generated_data, n_trials=500)
print("Meilleurs paramètres :", results["best_params"])
print(f"Meilleure accuracy : {results['best_accuracy']:.5f}")
# Out:
# [I 2025-03-03 22:33:25,439] A new study created in memory with name: no-name-e8a22ff4-8b85-4429-92c8-6288f579fcad
# [I 2025-03-03 22:33:25,457] Trial 0 finished with value: 0.9298611111111111 and parameters: {'ref_cells': 3, 'guard_cells': 99, 'far': 0.0020844545440869126, 'margin': 1.8268631854080135}. Best is trial 0 with value: 0.9298611111111111.
# [I 2025-03-03 22:33:25,475] Trial 1 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 43, 'guard_cells': 93, 'far': 0.0066440911159860675, 'margin': 1.9553917244497496}. Best is trial 1 with value: 0.9305555555555556.
# [I 2025-03-03 22:33:25,497] Trial 2 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 62, 'guard_cells': 0, 'far': 0.0023171018691767738, 'margin': 1.9384870839244888}. Best is trial 1 with value: 0.9305555555555556.
# [I 2025-03-03 22:33:25,517] Trial 3 finished with value: 0.9638888888888889 and parameters: {'ref_cells': 40, 'guard_cells': 42, 'far': 0.0006474877026150438, 'margin': 1.3795071955186111}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,532] Trial 4 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 47, 'guard_cells': 34, 'far': 0.008233131729529499, 'margin': 1.6748874311680921}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,549] Trial 5 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 44, 'guard_cells': 74, 'far': 0.005541686803073759, 'margin': 1.9323010986836069}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,565] Trial 6 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 99, 'guard_cells': 71, 'far': 0.006949222380113536, 'margin': 1.7419915783665412}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,576] Trial 7 finished with value: 0.9402777777777778 and parameters: {'ref_cells': 9, 'guard_cells': 95, 'far': 0.0012139712162645318, 'margin': 1.2822446347887184}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,588] Trial 8 finished with value: 0.80625 and parameters: {'ref_cells': 89, 'guard_cells': 54, 'far': 0.008181513143842994, 'margin': 1.174191534937469}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,601] Trial 9 finished with value: 0.8048611111111111 and parameters: {'ref_cells': 71, 'guard_cells': 79, 'far': 0.00420590777648497, 'margin': 1.174331127497195}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,624] Trial 10 finished with value: 0.9361111111111111 and parameters: {'ref_cells': 30, 'guard_cells': 26, 'far': 0.0037666768468417955, 'margin': 1.430190725646417}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,647] Trial 11 finished with value: 0.9479166666666666 and parameters: {'ref_cells': 9, 'guard_cells': 42, 'far': 0.0010303498162024015, 'margin': 1.3936227380919433}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,674] Trial 12 finished with value: 0.9319444444444445 and parameters: {'ref_cells': 21, 'guard_cells': 42, 'far': 0.0009310324151787736, 'margin': 1.4930944574964693}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,698] Trial 13 finished with value: 0.6340277777777777 and parameters: {'ref_cells': 24, 'guard_cells': 21, 'far': 0.0005075222134005644, 'margin': 1.0245288157818755}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,721] Trial 14 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 13, 'guard_cells': 55, 'far': 0.0035136924843209116, 'margin': 1.3512622934554075}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,744] Trial 15 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 62, 'guard_cells': 57, 'far': 0.0033232054569178565, 'margin': 1.6118004812119868}. Best is trial 3 with value: 0.9638888888888889.
# [I 2025-03-03 22:33:25,767] Trial 16 finished with value: 0.9701388888888889 and parameters: {'ref_cells': 33, 'guard_cells': 12, 'far': 0.009972977151787979, 'margin': 1.3649279669312975}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,789] Trial 17 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 32, 'guard_cells': 5, 'far': 0.009808768244389712, 'margin': 1.578125963056974}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,817] Trial 18 finished with value: 0.9111111111111111 and parameters: {'ref_cells': 60, 'guard_cells': 17, 'far': 0.009722315613172695, 'margin': 1.2495364518236942}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,844] Trial 19 finished with value: 0.6347222222222222 and parameters: {'ref_cells': 38, 'guard_cells': 15, 'far': 0.004990035932135258, 'margin': 1.0289460682720786}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,867] Trial 20 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 77, 'guard_cells': 9, 'far': 0.006259196019162081, 'margin': 1.506060293880691}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,889] Trial 21 finished with value: 0.9506944444444444 and parameters: {'ref_cells': 16, 'guard_cells': 62, 'far': 0.00247718274737804, 'margin': 1.341073445564974}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,913] Trial 22 finished with value: 0.9701388888888889 and parameters: {'ref_cells': 33, 'guard_cells': 42, 'far': 0.004783316748444314, 'margin': 1.3201890928348332}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,936] Trial 23 finished with value: 0.7888888888888889 and parameters: {'ref_cells': 53, 'guard_cells': 32, 'far': 0.008165807269159836, 'margin': 1.158180011300145}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,964] Trial 24 finished with value: 0.9340277777777778 and parameters: {'ref_cells': 33, 'guard_cells': 43, 'far': 0.004773766382319886, 'margin': 1.4581091110243145}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:25,990] Trial 25 finished with value: 0.9347222222222222 and parameters: {'ref_cells': 25, 'guard_cells': 34, 'far': 0.0073681563746775085, 'margin': 1.2602590990081635}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:26,017] Trial 26 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 52, 'guard_cells': 48, 'far': 0.005778213242227228, 'margin': 1.55108286958813}. Best is trial 16 with value: 0.9701388888888889.
# [I 2025-03-03 22:33:26,041] Trial 27 finished with value: 0.9729166666666667 and parameters: {'ref_cells': 38, 'guard_cells': 25, 'far': 0.0027864586148734455, 'margin': 1.3303953900200398}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,064] Trial 28 finished with value: 0.9590277777777778 and parameters: {'ref_cells': 36, 'guard_cells': 24, 'far': 0.002946243323853046, 'margin': 1.3070683478880434}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,087] Trial 29 finished with value: 0.7770833333333333 and parameters: {'ref_cells': 27, 'guard_cells': 29, 'far': 0.0017943706870975195, 'margin': 1.1462153115837874}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,111] Trial 30 finished with value: 0.7722222222222223 and parameters: {'ref_cells': 2, 'guard_cells': 12, 'far': 0.004268638605682285, 'margin': 1.0730655234230038}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,134] Trial 31 finished with value: 0.9631944444444445 and parameters: {'ref_cells': 39, 'guard_cells': 37, 'far': 0.001703198229747476, 'margin': 1.3907654843486617}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,156] Trial 32 finished with value: 0.8840277777777777 and parameters: {'ref_cells': 42, 'guard_cells': 20, 'far': 0.0025371409591743166, 'margin': 1.2313922225588496}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,180] Trial 33 finished with value: 0.9631944444444445 and parameters: {'ref_cells': 55, 'guard_cells': 48, 'far': 0.004313412593742093, 'margin': 1.386597970083522}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,203] Trial 34 finished with value: 0.9354166666666667 and parameters: {'ref_cells': 46, 'guard_cells': 1, 'far': 0.002971942805694066, 'margin': 1.4456827837298476}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,225] Trial 35 finished with value: 0.9673611111111111 and parameters: {'ref_cells': 22, 'guard_cells': 38, 'far': 0.008902395747813667, 'margin': 1.3251225358769132}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,246] Trial 36 finished with value: 0.8965277777777778 and parameters: {'ref_cells': 19, 'guard_cells': 28, 'far': 0.009044890479716761, 'margin': 1.2171534542578617}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,269] Trial 37 finished with value: 0.9701388888888889 and parameters: {'ref_cells': 27, 'guard_cells': 38, 'far': 0.00928420947562166, 'margin': 1.3300648710759977}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,292] Trial 38 finished with value: 0.7388888888888889 and parameters: {'ref_cells': 29, 'guard_cells': 9, 'far': 0.009108854470252009, 'margin': 1.108196355198287}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,315] Trial 39 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 35, 'guard_cells': 64, 'far': 0.007580843042012455, 'margin': 1.819310132609336}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,375] Trial 40 finished with value: 0.9645833333333333 and parameters: {'ref_cells': 48, 'guard_cells': 83, 'far': 0.006362937143642041, 'margin': 1.310331867635776}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,396] Trial 41 finished with value: 0.9645833333333333 and parameters: {'ref_cells': 21, 'guard_cells': 38, 'far': 0.009129604536798374, 'margin': 1.3378518723141586}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,419] Trial 42 finished with value: 0.9361111111111111 and parameters: {'ref_cells': 8, 'guard_cells': 22, 'far': 0.008572378840246996, 'margin': 1.283406405869198}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,443] Trial 43 finished with value: 0.9416666666666667 and parameters: {'ref_cells': 14, 'guard_cells': 35, 'far': 0.009932345031543666, 'margin': 1.4214001032360764}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,467] Trial 44 finished with value: 0.8631944444444445 and parameters: {'ref_cells': 43, 'guard_cells': 30, 'far': 0.009459394798318532, 'margin': 1.2061461445116313}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,489] Trial 45 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 29, 'guard_cells': 44, 'far': 0.008779687940211398, 'margin': 1.4883692343037862}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,510] Trial 46 finished with value: 0.9555555555555556 and parameters: {'ref_cells': 24, 'guard_cells': 50, 'far': 0.007920874896971984, 'margin': 1.3522427974181699}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,531] Trial 47 finished with value: 0.9520833333333333 and parameters: {'ref_cells': 17, 'guard_cells': 40, 'far': 0.006981132368151359, 'margin': 1.2884614695180576}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,553] Trial 48 finished with value: 0.9458333333333333 and parameters: {'ref_cells': 33, 'guard_cells': 18, 'far': 0.005578334889316682, 'margin': 1.4126878829294025}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,575] Trial 49 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 7, 'guard_cells': 26, 'far': 0.009567866289025607, 'margin': 1.6726270340813596}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,595] Trial 50 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 22, 'guard_cells': 46, 'far': 0.008433395223975447, 'margin': 1.525296951361391}. Best is trial 27 with value: 0.9729166666666667.
# [I 2025-03-03 22:33:26,618] Trial 51 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 50, 'guard_cells': 70, 'far': 0.006151615711793253, 'margin': 1.3279998389985503}. Best is trial 51 with value: 0.9743055555555555.
# [I 2025-03-03 22:33:26,640] Trial 52 finished with value: 0.9708333333333333 and parameters: {'ref_cells': 40, 'guard_cells': 69, 'far': 0.0038344645650780678, 'margin': 1.3237281340674196}. Best is trial 51 with value: 0.9743055555555555.
# [I 2025-03-03 22:33:26,663] Trial 53 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 69, 'guard_cells': 73, 'far': 0.003826572945432732, 'margin': 1.3613949800499392}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,686] Trial 54 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 72, 'guard_cells': 71, 'far': 0.0038565288682888624, 'margin': 1.3653303264821417}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,716] Trial 55 finished with value: 0.93125 and parameters: {'ref_cells': 68, 'guard_cells': 73, 'far': 0.0038783881960695104, 'margin': 1.4641666810067846}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,737] Trial 56 finished with value: 0.9784722222222222 and parameters: {'ref_cells': 82, 'guard_cells': 81, 'far': 0.003338524843407713, 'margin': 1.3705958883061735}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,760] Trial 57 finished with value: 0.9090277777777778 and parameters: {'ref_cells': 83, 'guard_cells': 87, 'far': 0.0031844208243766332, 'margin': 1.2613189429738183}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,783] Trial 58 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 98, 'guard_cells': 69, 'far': 0.003626045065078922, 'margin': 1.9856198852004767}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,806] Trial 59 finished with value: 0.8256944444444444 and parameters: {'ref_cells': 70, 'guard_cells': 78, 'far': 0.004535909406505712, 'margin': 1.1901683817242688}. Best is trial 53 with value: 0.9791666666666666.
# [I 2025-03-03 22:33:26,830] Trial 60 finished with value: 0.9805555555555555 and parameters: {'ref_cells': 78, 'guard_cells': 98, 'far': 0.003963145802442718, 'margin': 1.363034908345504}. Best is trial 60 with value: 0.9805555555555555.
# [I 2025-03-03 22:33:26,854] Trial 61 finished with value: 0.9805555555555555 and parameters: {'ref_cells': 77, 'guard_cells': 90, 'far': 0.0038558285384778456, 'margin': 1.3678434903286478}. Best is trial 60 with value: 0.9805555555555555.
# [I 2025-03-03 22:33:26,877] Trial 62 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 77, 'guard_cells': 99, 'far': 0.005226110069183406, 'margin': 1.3817320876491408}. Best is trial 60 with value: 0.9805555555555555.
# [I 2025-03-03 22:33:26,905] Trial 63 finished with value: 0.95625 and parameters: {'ref_cells': 87, 'guard_cells': 93, 'far': 0.002752016390116549, 'margin': 1.4064509289123084}. Best is trial 60 with value: 0.9805555555555555.
# [I 2025-03-03 22:33:26,937] Trial 64 finished with value: 0.9819444444444444 and parameters: {'ref_cells': 75, 'guard_cells': 88, 'far': 0.0019933734683767862, 'margin': 1.3669793961523073}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:26,961] Trial 65 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 75, 'guard_cells': 87, 'far': 0.0033479133985805597, 'margin': 1.476788445650902}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:26,983] Trial 66 finished with value: 0.9416666666666667 and parameters: {'ref_cells': 81, 'guard_cells': 90, 'far': 0.001895617776363443, 'margin': 1.4343276531504134}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,007] Trial 67 finished with value: 0.9715277777777778 and parameters: {'ref_cells': 63, 'guard_cells': 78, 'far': 0.004061897991554326, 'margin': 1.377793118974547}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,029] Trial 68 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 91, 'guard_cells': 100, 'far': 0.0023800587886076276, 'margin': 1.5782806105650737}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,050] Trial 69 finished with value: 0.9263888888888889 and parameters: {'ref_cells': 73, 'guard_cells': 85, 'far': 0.0012418733360314484, 'margin': 1.2744167190444087}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,076] Trial 70 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 80, 'guard_cells': 80, 'far': 0.005895824562911314, 'margin': 1.5258928597506156}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,104] Trial 71 finished with value: 0.9805555555555555 and parameters: {'ref_cells': 66, 'guard_cells': 97, 'far': 0.002141232122296075, 'margin': 1.3598434563654618}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,132] Trial 72 finished with value: 0.9784722222222222 and parameters: {'ref_cells': 66, 'guard_cells': 91, 'far': 0.0015629502332207535, 'margin': 1.3607846306234432}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,159] Trial 73 finished with value: 0.94375 and parameters: {'ref_cells': 66, 'guard_cells': 97, 'far': 0.0021212277846876662, 'margin': 1.4374991763325393}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,186] Trial 74 finished with value: 0.8743055555555556 and parameters: {'ref_cells': 60, 'guard_cells': 96, 'far': 0.0013363560512124157, 'margin': 1.2367245756654681}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,212] Trial 75 finished with value: 0.9583333333333334 and parameters: {'ref_cells': 55, 'guard_cells': 91, 'far': 0.0007971532600410446, 'margin': 1.4037612681926326}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,238] Trial 76 finished with value: 0.9520833333333333 and parameters: {'ref_cells': 85, 'guard_cells': 82, 'far': 0.0015629535247986654, 'margin': 1.2979020540266126}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,263] Trial 77 finished with value: 0.98125 and parameters: {'ref_cells': 65, 'guard_cells': 92, 'far': 0.002122109681217734, 'margin': 1.3546693287261296}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,285] Trial 78 finished with value: 0.9784722222222222 and parameters: {'ref_cells': 64, 'guard_cells': 92, 'far': 0.0022312814526386443, 'margin': 1.3621940585941505}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,308] Trial 79 finished with value: 0.9319444444444445 and parameters: {'ref_cells': 79, 'guard_cells': 94, 'far': 0.0026277916624372856, 'margin': 1.451815639113248}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,333] Trial 80 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 68, 'guard_cells': 86, 'far': 0.0030272691908908326, 'margin': 1.361226453220086}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,355] Trial 81 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 68, 'guard_cells': 89, 'far': 0.0030102052774841244, 'margin': 1.3681099388293338}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,378] Trial 82 finished with value: 0.9625 and parameters: {'ref_cells': 75, 'guard_cells': 88, 'far': 0.003046403896265451, 'margin': 1.3961685866839586}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,399] Trial 83 finished with value: 0.9472222222222222 and parameters: {'ref_cells': 58, 'guard_cells': 97, 'far': 0.0034660429252691034, 'margin': 1.425489969486397}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,427] Trial 84 finished with value: 0.95 and parameters: {'ref_cells': 69, 'guard_cells': 84, 'far': 0.0019232423065930987, 'margin': 1.2953927656931787}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,448] Trial 85 finished with value: 0.9006944444444445 and parameters: {'ref_cells': 75, 'guard_cells': 75, 'far': 0.0032005633310109266, 'margin': 1.2507531149594733}. Best is trial 64 with value: 0.9819444444444444.
# [I 2025-03-03 22:33:27,473] Trial 86 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 91, 'guard_cells': 89, 'far': 0.0027964645493427902, 'margin': 1.3503810507973293}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,495] Trial 87 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 91, 'guard_cells': 89, 'far': 0.0028420330317792467, 'margin': 1.3515388514913744}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,516] Trial 88 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 95, 'guard_cells': 94, 'far': 0.002882110859199659, 'margin': 1.3447918267950008}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,538] Trial 89 finished with value: 0.9631944444444445 and parameters: {'ref_cells': 92, 'guard_cells': 95, 'far': 0.0024518953715157153, 'margin': 1.3087648640170633}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,564] Trial 90 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 96, 'guard_cells': 86, 'far': 0.0021317569575874844, 'margin': 1.5089562120439108}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,591] Trial 91 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 92, 'guard_cells': 89, 'far': 0.0029487878336020637, 'margin': 1.34992223358894}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,614] Trial 92 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 95, 'guard_cells': 89, 'far': 0.002801893370973778, 'margin': 1.335999559791702}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,636] Trial 93 finished with value: 0.9256944444444445 and parameters: {'ref_cells': 94, 'guard_cells': 98, 'far': 0.0027714154937485743, 'margin': 1.2726102073174173}. Best is trial 86 with value: 0.9902777777777778.
# [I 2025-03-03 22:33:27,659] Trial 94 finished with value: 0.9944444444444445 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.002308384445260484, 'margin': 1.3418950043440918}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,681] Trial 95 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.0025921345929860763, 'margin': 1.3332917823755486}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,710] Trial 96 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 100, 'guard_cells': 93, 'far': 0.002604398870663509, 'margin': 1.3305143670790485}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,734] Trial 97 finished with value: 0.9930555555555556 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.002549052621155869, 'margin': 1.3389614297292638}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,764] Trial 98 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 100, 'guard_cells': 100, 'far': 0.0025967531329759487, 'margin': 1.3374356056256123}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,791] Trial 99 finished with value: 0.9819444444444444 and parameters: {'ref_cells': 100, 'guard_cells': 100, 'far': 0.002581204414750353, 'margin': 1.3288571738788657}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,822] Trial 100 finished with value: 0.8493055555555555 and parameters: {'ref_cells': 97, 'guard_cells': 93, 'far': 0.0028434328932158805, 'margin': 1.215919234012032}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,847] Trial 101 finished with value: 0.9625 and parameters: {'ref_cells': 94, 'guard_cells': 95, 'far': 0.0023725773541201887, 'margin': 1.3093301419896566}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,879] Trial 102 finished with value: 0.9465277777777777 and parameters: {'ref_cells': 90, 'guard_cells': 88, 'far': 0.0026464378152269395, 'margin': 1.2918608184172857}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,913] Trial 103 finished with value: 0.9666666666666667 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.001860167736643584, 'margin': 1.3918959049910515}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,938] Trial 104 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 88, 'guard_cells': 84, 'far': 0.003629951445603333, 'margin': 1.3391203718197178}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,962] Trial 105 finished with value: 0.9875 and parameters: {'ref_cells': 95, 'guard_cells': 83, 'far': 0.0035563823858346865, 'margin': 1.3390246574553477}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:27,988] Trial 106 finished with value: 0.8708333333333333 and parameters: {'ref_cells': 87, 'guard_cells': 83, 'far': 0.0035395319267876747, 'margin': 1.233272950347967}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,016] Trial 107 finished with value: 0.9159722222222222 and parameters: {'ref_cells': 95, 'guard_cells': 76, 'far': 0.0031286976609234294, 'margin': 1.2684412304832093}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,043] Trial 108 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 93, 'guard_cells': 84, 'far': 0.00360374708516631, 'margin': 1.339025071938883}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,069] Trial 109 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 93, 'guard_cells': 84, 'far': 0.003610000325383448, 'margin': 1.4136095793574388}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,097] Trial 110 finished with value: 0.9875 and parameters: {'ref_cells': 88, 'guard_cells': 90, 'far': 0.0033111428379014865, 'margin': 1.346441530920228}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,123] Trial 111 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 88, 'guard_cells': 90, 'far': 0.00441670516304943, 'margin': 1.3412708075903348}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,148] Trial 112 finished with value: 0.9659722222222222 and parameters: {'ref_cells': 86, 'guard_cells': 90, 'far': 0.003312862595924665, 'margin': 1.3123069582482052}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,174] Trial 113 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 90, 'guard_cells': 80, 'far': 0.0029086332706180448, 'margin': 1.8977881440428765}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,198] Trial 114 finished with value: 0.9673611111111111 and parameters: {'ref_cells': 97, 'guard_cells': 89, 'far': 0.004161448262649349, 'margin': 1.3893353723583524}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,227] Trial 115 finished with value: 0.9375 and parameters: {'ref_cells': 89, 'guard_cells': 96, 'far': 0.00435113892907298, 'margin': 1.279529924972356}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,252] Trial 116 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 84, 'guard_cells': 86, 'far': 0.00479701138303809, 'margin': 1.344315252915623}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,277] Trial 117 finished with value: 0.9597222222222223 and parameters: {'ref_cells': 84, 'guard_cells': 86, 'far': 0.004588649630898414, 'margin': 1.3057850350402171}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,303] Trial 118 finished with value: 0.8979166666666667 and parameters: {'ref_cells': 88, 'guard_cells': 100, 'far': 0.005108223546581242, 'margin': 1.249355720462186}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,333] Trial 119 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 98, 'guard_cells': 82, 'far': 0.00491705056273861, 'margin': 1.3466923236417816}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,357] Trial 120 finished with value: 0.9458333333333333 and parameters: {'ref_cells': 91, 'guard_cells': 82, 'far': 0.005334383081596716, 'margin': 1.4190081297661368}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,393] Trial 121 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 98, 'guard_cells': 91, 'far': 0.004571597882176569, 'margin': 1.3456846873996102}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,418] Trial 122 finished with value: 0.9680555555555556 and parameters: {'ref_cells': 98, 'guard_cells': 91, 'far': 0.0048441048077695805, 'margin': 1.3843659935634245}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,443] Trial 123 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 89, 'guard_cells': 79, 'far': 0.0046545508896081965, 'margin': 1.3434831692418328}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,468] Trial 124 finished with value: 0.96875 and parameters: {'ref_cells': 96, 'guard_cells': 86, 'far': 0.004419052025982191, 'margin': 1.3131696602593885}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,495] Trial 125 finished with value: 0.9527777777777777 and parameters: {'ref_cells': 92, 'guard_cells': 77, 'far': 0.004974193041068465, 'margin': 1.2909622392327558}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,521] Trial 126 finished with value: 0.95625 and parameters: {'ref_cells': 98, 'guard_cells': 81, 'far': 0.004018522274294773, 'margin': 1.4035612809923534}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,551] Trial 127 finished with value: 0.9333333333333333 and parameters: {'ref_cells': 85, 'guard_cells': 57, 'far': 0.0037238184390127045, 'margin': 1.4535372302871137}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,576] Trial 128 finished with value: 0.9875 and parameters: {'ref_cells': 95, 'guard_cells': 92, 'far': 0.005417928081164576, 'margin': 1.350813913266869}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,601] Trial 129 finished with value: 0.9638888888888889 and parameters: {'ref_cells': 92, 'guard_cells': 88, 'far': 0.005675577671102445, 'margin': 1.391151413779817}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,628] Trial 130 finished with value: 0.9375 and parameters: {'ref_cells': 83, 'guard_cells': 91, 'far': 0.004829925034860678, 'margin': 1.435148339251372}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,654] Trial 131 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 95, 'guard_cells': 92, 'far': 0.005169927834345594, 'margin': 1.347371999999853}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,682] Trial 132 finished with value: 0.9736111111111111 and parameters: {'ref_cells': 88, 'guard_cells': 85, 'far': 0.0050869491145655995, 'margin': 1.3188181651244693}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,711] Trial 133 finished with value: 0.9715277777777778 and parameters: {'ref_cells': 98, 'guard_cells': 87, 'far': 0.004286858983373144, 'margin': 1.3788929856135979}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,739] Trial 134 finished with value: 0.9375 and parameters: {'ref_cells': 94, 'guard_cells': 95, 'far': 0.0032501526883349525, 'margin': 1.2831670189382445}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,767] Trial 135 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 96, 'guard_cells': 90, 'far': 0.0033953727658990645, 'margin': 1.3515809814441049}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,797] Trial 136 finished with value: 0.9152777777777777 and parameters: {'ref_cells': 96, 'guard_cells': 93, 'far': 0.004634834738954965, 'margin': 1.2592427535311417}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,822] Trial 137 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 91, 'guard_cells': 83, 'far': 0.002314820030517371, 'margin': 1.313944991442639}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,847] Trial 138 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 97, 'guard_cells': 97, 'far': 0.005217411748749366, 'margin': 1.3486680899611887}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,873] Trial 139 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 93, 'guard_cells': 88, 'far': 0.004114271643599805, 'margin': 1.3794029718282448}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,899] Trial 140 finished with value: 0.9493055555555555 and parameters: {'ref_cells': 95, 'guard_cells': 91, 'far': 0.005910723648935945, 'margin': 1.2900288841670102}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,925] Trial 141 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 86, 'guard_cells': 90, 'far': 0.0033995151999936355, 'margin': 1.3423873592395867}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,951] Trial 142 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 98, 'guard_cells': 85, 'far': 0.0034455084392448964, 'margin': 1.3266497584671444}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:28,977] Trial 143 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 86, 'guard_cells': 93, 'far': 0.002892540116572217, 'margin': 1.3503997592544865}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,004] Trial 144 finished with value: 0.9527777777777777 and parameters: {'ref_cells': 82, 'guard_cells': 95, 'far': 0.003068291914970876, 'margin': 1.410420508314218}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,031] Trial 145 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 85, 'guard_cells': 93, 'far': 0.004961164744166445, 'margin': 1.3668533912665912}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,064] Trial 146 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 91, 'guard_cells': 89, 'far': 0.0029595781718608134, 'margin': 1.3525525506912754}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,099] Trial 147 finished with value: 0.95625 and parameters: {'ref_cells': 86, 'guard_cells': 89, 'far': 0.003021083346980726, 'margin': 1.305124798559409}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,130] Trial 148 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 90, 'guard_cells': 87, 'far': 0.002386634686330825, 'margin': 1.3778088517717975}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,158] Trial 149 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 92, 'guard_cells': 98, 'far': 0.002893605024937705, 'margin': 1.4706574758944284}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,181] Trial 150 finished with value: 0.9604166666666667 and parameters: {'ref_cells': 89, 'guard_cells': 94, 'far': 0.003201681210891801, 'margin': 1.3988949669550743}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,205] Trial 151 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 87, 'guard_cells': 91, 'far': 0.002683627551038433, 'margin': 1.3536713681389605}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,229] Trial 152 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 93, 'guard_cells': 89, 'far': 0.0028835547888292055, 'margin': 1.3461016431211035}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,252] Trial 153 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 99, 'guard_cells': 92, 'far': 0.005522339332236331, 'margin': 1.322842122881175}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,278] Trial 154 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 90, 'guard_cells': 96, 'far': 0.004479758397959672, 'margin': 1.378446087478327}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,302] Trial 155 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 96, 'guard_cells': 90, 'far': 0.0034286574839415052, 'margin': 1.657957744836898}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,329] Trial 156 finished with value: 0.98125 and parameters: {'ref_cells': 94, 'guard_cells': 86, 'far': 0.003782899722112163, 'margin': 1.327197295286002}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,353] Trial 157 finished with value: 0.9576388888888889 and parameters: {'ref_cells': 91, 'guard_cells': 93, 'far': 0.0024406660546603437, 'margin': 1.302217446262504}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,378] Trial 158 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 80, 'guard_cells': 88, 'far': 0.0027668752396549294, 'margin': 1.3541418183455867}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,406] Trial 159 finished with value: 0.93125 and parameters: {'ref_cells': 84, 'guard_cells': 96, 'far': 0.0030548250092431953, 'margin': 1.2772249127046582}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,435] Trial 160 finished with value: 0.9416666666666667 and parameters: {'ref_cells': 97, 'guard_cells': 90, 'far': 0.0032240587654989708, 'margin': 1.428530290469571}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,464] Trial 161 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 93, 'guard_cells': 89, 'far': 0.0028898320318411675, 'margin': 1.3447985481594436}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,487] Trial 162 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 100, 'guard_cells': 92, 'far': 0.002796238507481124, 'margin': 1.364577459554167}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,512] Trial 163 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 87, 'guard_cells': 85, 'far': 0.004711625942249556, 'margin': 1.3387430479420546}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,541] Trial 164 finished with value: 0.9763888888888889 and parameters: {'ref_cells': 88, 'guard_cells': 85, 'far': 0.004803212923846797, 'margin': 1.3221609961522218}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,565] Trial 165 finished with value: 0.9576388888888889 and parameters: {'ref_cells': 82, 'guard_cells': 94, 'far': 0.004487106719284838, 'margin': 1.3990912043297201}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,588] Trial 166 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 90, 'guard_cells': 81, 'far': 0.004658243910724082, 'margin': 1.3409019608612558}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,610] Trial 167 finished with value: 0.975 and parameters: {'ref_cells': 86, 'guard_cells': 81, 'far': 0.005068144959332935, 'margin': 1.3740503907959845}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,632] Trial 168 finished with value: 0.9534722222222223 and parameters: {'ref_cells': 87, 'guard_cells': 87, 'far': 0.00420631784066118, 'margin': 1.2981593332166501}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,654] Trial 169 finished with value: 0.98125 and parameters: {'ref_cells': 90, 'guard_cells': 83, 'far': 0.00475410812177994, 'margin': 1.3277097638907884}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,677] Trial 170 finished with value: 0.9659722222222222 and parameters: {'ref_cells': 84, 'guard_cells': 80, 'far': 0.002493820218410996, 'margin': 1.3935009618329712}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,700] Trial 171 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 92, 'guard_cells': 85, 'far': 0.004923265491823867, 'margin': 1.3478248848522176}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,724] Trial 172 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 91, 'guard_cells': 85, 'far': 0.00530218494292641, 'margin': 1.3558859267824102}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,746] Trial 173 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 92, 'guard_cells': 86, 'far': 0.005389826597902711, 'margin': 1.363502196629748}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,779] Trial 174 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 94, 'guard_cells': 84, 'far': 0.004985836606901608, 'margin': 1.306666808083125}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,811] Trial 175 finished with value: 0.9784722222222222 and parameters: {'ref_cells': 88, 'guard_cells': 66, 'far': 0.005345649513576617, 'margin': 1.3236472812528695}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,845] Trial 176 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 96, 'guard_cells': 88, 'far': 0.005199499936692084, 'margin': 1.7821708925297184}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,873] Trial 177 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 92, 'guard_cells': 84, 'far': 0.005770213730752703, 'margin': 1.3551009500163813}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,897] Trial 178 finished with value: 0.975 and parameters: {'ref_cells': 94, 'guard_cells': 87, 'far': 0.0022105622264973037, 'margin': 1.3797726468788136}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,926] Trial 179 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 89, 'guard_cells': 90, 'far': 0.004908944424618952, 'margin': 1.3442993728098889}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,953] Trial 180 finished with value: 0.9493055555555555 and parameters: {'ref_cells': 86, 'guard_cells': 92, 'far': 0.004875219302705147, 'margin': 1.4146689184117887}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:29,977] Trial 181 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 90, 'guard_cells': 89, 'far': 0.005066558108859941, 'margin': 1.3370123362990467}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,002] Trial 182 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 89, 'guard_cells': 94, 'far': 0.005195649216662907, 'margin': 1.3311591340170466}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,025] Trial 183 finished with value: 0.9611111111111111 and parameters: {'ref_cells': 88, 'guard_cells': 90, 'far': 0.005014660158122918, 'margin': 1.3044088464437453}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,049] Trial 184 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 96, 'guard_cells': 85, 'far': 0.005477183076262139, 'margin': 1.3403384612086229}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,073] Trial 185 finished with value: 0.9451388888888889 and parameters: {'ref_cells': 96, 'guard_cells': 85, 'far': 0.0055542783029366655, 'margin': 1.2859237714196161}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,100] Trial 186 finished with value: 0.975 and parameters: {'ref_cells': 98, 'guard_cells': 82, 'far': 0.005331587356549608, 'margin': 1.3177868912689696}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,125] Trial 187 finished with value: 0.96875 and parameters: {'ref_cells': 95, 'guard_cells': 86, 'far': 0.00592449814201368, 'margin': 1.3807748488837155}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,149] Trial 188 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 100, 'guard_cells': 79, 'far': 0.005515078461975994, 'margin': 1.3415153881891038}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,174] Trial 189 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 100, 'guard_cells': 83, 'far': 0.005524980474546622, 'margin': 1.368348683313455}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,198] Trial 190 finished with value: 0.6506944444444445 and parameters: {'ref_cells': 98, 'guard_cells': 78, 'far': 0.0061444450392273905, 'margin': 1.0544421940994602}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,223] Trial 191 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 93, 'guard_cells': 87, 'far': 0.005135099092413035, 'margin': 1.3455500518052794}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,260] Trial 192 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 94, 'guard_cells': 87, 'far': 0.005665444941951588, 'margin': 1.327986280151928}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,300] Trial 193 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 92, 'guard_cells': 84, 'far': 0.0051940414303974876, 'margin': 1.3406323838035685}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,330] Trial 194 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 92, 'guard_cells': 82, 'far': 0.004863049537279191, 'margin': 1.3187344991798873}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,357] Trial 195 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 100, 'guard_cells': 85, 'far': 0.005100911690557991, 'margin': 1.3639147569035983}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,385] Trial 196 finished with value: 0.9916666666666667 and parameters: {'ref_cells': 90, 'guard_cells': 84, 'far': 0.005384101413838228, 'margin': 1.3389254344077333}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,414] Trial 197 finished with value: 0.9534722222222223 and parameters: {'ref_cells': 97, 'guard_cells': 79, 'far': 0.0056074989012908135, 'margin': 1.2936206899428038}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,446] Trial 198 finished with value: 0.7361111111111112 and parameters: {'ref_cells': 91, 'guard_cells': 76, 'far': 0.005407330015550605, 'margin': 1.1190878852721333}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,476] Trial 199 finished with value: 0.9618055555555556 and parameters: {'ref_cells': 93, 'guard_cells': 84, 'far': 0.0052677091451594745, 'margin': 1.3895436594277149}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:30,505] Trial 200 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 96, 'guard_cells': 80, 'far': 0.006529796781341801, 'margin': 1.334538089341092}. Best is trial 94 with value: 0.9944444444444445.
# ...
# [I 2025-03-03 22:33:37,109] Trial 434 finished with value: 0.85625 and parameters: {'ref_cells': 98, 'guard_cells': 89, 'far': 0.004801009912294794, 'margin': 1.2195342377003806}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,137] Trial 435 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 94, 'guard_cells': 87, 'far': 0.004199868580214544, 'margin': 1.374649939621495}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,167] Trial 436 finished with value: 0.9465277777777777 and parameters: {'ref_cells': 98, 'guard_cells': 84, 'far': 0.0022126166672422963, 'margin': 1.4210372967419258}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,197] Trial 437 finished with value: 0.98125 and parameters: {'ref_cells': 96, 'guard_cells': 91, 'far': 0.006585021012800976, 'margin': 1.3229784259823298}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,231] Trial 438 finished with value: 0.9909722222222223 and parameters: {'ref_cells': 93, 'guard_cells': 10, 'far': 0.0006620366181598076, 'margin': 1.35002154409251}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,262] Trial 439 finished with value: 0.9590277777777778 and parameters: {'ref_cells': 44, 'guard_cells': 42, 'far': 0.0012413724279421088, 'margin': 1.3893862761510845}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,293] Trial 440 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 93, 'guard_cells': 69, 'far': 0.0006565645944309595, 'margin': 1.3651178070565022}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,322] Trial 441 finished with value: 0.9597222222222223 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.003986910866457427, 'margin': 1.3059663302155198}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,365] Trial 442 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 25, 'guard_cells': 93, 'far': 0.0008594879480546239, 'margin': 1.8400646515882393}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,409] Trial 443 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 95, 'guard_cells': 97, 'far': 0.004391988843703512, 'margin': 1.3496063589389888}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,459] Trial 444 finished with value: 0.9805555555555555 and parameters: {'ref_cells': 97, 'guard_cells': 10, 'far': 0.0038060381905757512, 'margin': 1.3285278590230736}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,491] Trial 445 finished with value: 0.9625 and parameters: {'ref_cells': 93, 'guard_cells': 82, 'far': 0.0006332650385451109, 'margin': 1.39898956189317}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,524] Trial 446 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 96, 'guard_cells': 79, 'far': 0.003494675098989455, 'margin': 1.3715634859060475}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,554] Trial 447 finished with value: 0.9402777777777778 and parameters: {'ref_cells': 98, 'guard_cells': 12, 'far': 0.008525994577272796, 'margin': 1.2858820156059747}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,587] Trial 448 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 94, 'guard_cells': 89, 'far': 0.0027499002792688992, 'margin': 1.351070660954421}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,636] Trial 449 finished with value: 0.9625 and parameters: {'ref_cells': 19, 'guard_cells': 85, 'far': 0.0035968219818573927, 'margin': 1.3249274152567907}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,678] Trial 450 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 100, 'guard_cells': 87, 'far': 0.0045336865767864, 'margin': 1.4804251273734255}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,708] Trial 451 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 92, 'guard_cells': 92, 'far': 0.0015325993277908855, 'margin': 1.3423371100275552}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,740] Trial 452 finished with value: 0.98125 and parameters: {'ref_cells': 95, 'guard_cells': 7, 'far': 0.0016952169355161622, 'margin': 1.3732625857012961}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,771] Trial 453 finished with value: 0.9611111111111111 and parameters: {'ref_cells': 98, 'guard_cells': 83, 'far': 0.0032214758701903856, 'margin': 1.3048882720753696}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,800] Trial 454 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 93, 'guard_cells': 89, 'far': 0.004716400955659133, 'margin': 1.3565765264544611}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,830] Trial 455 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 96, 'guard_cells': 0, 'far': 0.0015161745905022902, 'margin': 1.3949525554128122}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,864] Trial 456 finished with value: 0.9784722222222222 and parameters: {'ref_cells': 97, 'guard_cells': 27, 'far': 0.00579800665623293, 'margin': 1.3263465156435919}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,898] Trial 457 finished with value: 0.9888888888888889 and parameters: {'ref_cells': 94, 'guard_cells': 84, 'far': 0.004986645894550464, 'margin': 1.3414821565672927}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,938] Trial 458 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 91, 'guard_cells': 45, 'far': 0.0029861091238984274, 'margin': 1.372563397312631}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:37,969] Trial 459 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 99, 'guard_cells': 87, 'far': 0.004169657881159923, 'margin': 1.3092706760036141}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,001] Trial 460 finished with value: 0.9173611111111111 and parameters: {'ref_cells': 93, 'guard_cells': 91, 'far': 0.0011220674338776535, 'margin': 1.2698871697780545}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,032] Trial 461 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 96, 'guard_cells': 21, 'far': 0.0005348482299750224, 'margin': 1.3557698381686571}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,063] Trial 462 finished with value: 0.9854166666666667 and parameters: {'ref_cells': 100, 'guard_cells': 96, 'far': 0.005544784481143965, 'margin': 1.3254066396951976}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,093] Trial 463 finished with value: 0.9368055555555556 and parameters: {'ref_cells': 90, 'guard_cells': 53, 'far': 0.00478161149828422, 'margin': 1.286252524578935}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,124] Trial 464 finished with value: 0.9694444444444444 and parameters: {'ref_cells': 95, 'guard_cells': 63, 'far': 0.006179421549921502, 'margin': 1.380455097929911}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,166] Trial 465 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 98, 'guard_cells': 81, 'far': 0.003300547314777857, 'margin': 1.3390966860513607}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,199] Trial 466 finished with value: 0.9840277777777777 and parameters: {'ref_cells': 88, 'guard_cells': 85, 'far': 0.0037297607421101367, 'margin': 1.362516695169448}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,244] Trial 467 finished with value: 0.9493055555555555 and parameters: {'ref_cells': 92, 'guard_cells': 89, 'far': 0.009400191388229884, 'margin': 1.4071956538247492}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,278] Trial 468 finished with value: 0.9666666666666667 and parameters: {'ref_cells': 97, 'guard_cells': 100, 'far': 0.005070935609356542, 'margin': 1.3101619865132363}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,316] Trial 469 finished with value: 0.9902777777777778 and parameters: {'ref_cells': 93, 'guard_cells': 87, 'far': 0.002578458215066543, 'margin': 1.3427193318729704}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,353] Trial 470 finished with value: 0.9798611111111111 and parameters: {'ref_cells': 78, 'guard_cells': 93, 'far': 0.00599396719849323, 'margin': 1.326365757922896}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,390] Trial 471 finished with value: 0.9881944444444445 and parameters: {'ref_cells': 95, 'guard_cells': 83, 'far': 0.00547476040014668, 'margin': 1.3552580218809465}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,423] Trial 472 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 91, 'guard_cells': 90, 'far': 0.0052918809788169655, 'margin': 1.7052315610478246}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,458] Trial 473 finished with value: 0.9777777777777777 and parameters: {'ref_cells': 100, 'guard_cells': 18, 'far': 0.006868080622823418, 'margin': 1.370327683694418}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,494] Trial 474 finished with value: 0.9611111111111111 and parameters: {'ref_cells': 98, 'guard_cells': 4, 'far': 0.004934451843138066, 'margin': 1.3922263834612165}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,530] Trial 475 finished with value: 0.9520833333333333 and parameters: {'ref_cells': 87, 'guard_cells': 86, 'far': 0.005651575936437208, 'margin': 1.2941191829567114}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,565] Trial 476 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 94, 'guard_cells': 84, 'far': 0.001838805167578518, 'margin': 1.3351150159254752}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,598] Trial 477 finished with value: 0.9708333333333333 and parameters: {'ref_cells': 96, 'guard_cells': 88, 'far': 0.004569783790821715, 'margin': 1.3134471330463204}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,635] Trial 478 finished with value: 0.6729166666666667 and parameters: {'ref_cells': 89, 'guard_cells': 80, 'far': 0.0027752400604192195, 'margin': 1.0748703036782563}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,670] Trial 479 finished with value: 0.9423611111111111 and parameters: {'ref_cells': 98, 'guard_cells': 58, 'far': 0.005095435339806823, 'margin': 1.4246421114163186}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,702] Trial 480 finished with value: 0.9875 and parameters: {'ref_cells': 91, 'guard_cells': 15, 'far': 0.005880143442446958, 'margin': 1.3548727618590424}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,732] Trial 481 finished with value: 0.9743055555555555 and parameters: {'ref_cells': 94, 'guard_cells': 86, 'far': 0.0048121939243653145, 'margin': 1.3768751862962778}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,763] Trial 482 finished with value: 0.9847222222222223 and parameters: {'ref_cells': 96, 'guard_cells': 91, 'far': 0.005410964176728549, 'margin': 1.3327737393751096}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,794] Trial 483 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 92, 'guard_cells': 48, 'far': 0.004310571800339817, 'margin': 1.356463849190006}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,823] Trial 484 finished with value: 0.9611111111111111 and parameters: {'ref_cells': 100, 'guard_cells': 82, 'far': 0.002424231260746234, 'margin': 1.3058086241266078}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,854] Trial 485 finished with value: 0.9576388888888889 and parameters: {'ref_cells': 33, 'guard_cells': 96, 'far': 0.005695778357722574, 'margin': 1.3916366961607842}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,890] Trial 486 finished with value: 0.9770833333333333 and parameters: {'ref_cells': 97, 'guard_cells': 85, 'far': 0.003910167323051215, 'margin': 1.3227800733211919}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,926] Trial 487 finished with value: 0.9555555555555556 and parameters: {'ref_cells': 13, 'guard_cells': 30, 'far': 0.0031527952407065865, 'margin': 1.3442296581595565}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,962] Trial 488 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 83, 'guard_cells': 89, 'far': 0.00506625260622794, 'margin': 1.3667368317444435}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:38,997] Trial 489 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 94, 'guard_cells': 93, 'far': 0.003405515600803214, 'margin': 1.3431234013654356}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,029] Trial 490 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 86, 'guard_cells': 87, 'far': 0.0052873203359335595, 'margin': 1.2947141206088657}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,066] Trial 491 finished with value: 0.9013888888888889 and parameters: {'ref_cells': 90, 'guard_cells': 84, 'far': 0.004672141113734978, 'margin': 1.2522897413965193}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,098] Trial 492 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 98, 'guard_cells': 76, 'far': 0.002941283268414366, 'margin': 1.321783992528774}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,127] Trial 493 finished with value: 0.7902777777777777 and parameters: {'ref_cells': 93, 'guard_cells': 90, 'far': 0.004919919785919911, 'margin': 1.1678293669947946}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,156] Trial 494 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 96, 'guard_cells': 82, 'far': 0.005546685002057492, 'margin': 1.3781763629316064}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,186] Trial 495 finished with value: 0.9868055555555556 and parameters: {'ref_cells': 89, 'guard_cells': 79, 'far': 0.004492692320757207, 'margin': 1.3569839907826136}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,216] Trial 496 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 100, 'guard_cells': 94, 'far': 0.00203873650958684, 'margin': 1.3349281774413924}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,245] Trial 497 finished with value: 0.9680555555555556 and parameters: {'ref_cells': 92, 'guard_cells': 87, 'far': 0.0052713334651868105, 'margin': 1.3125762407147334}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,276] Trial 498 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 95, 'guard_cells': 85, 'far': 0.004797287583275278, 'margin': 1.4098760167212385}. Best is trial 94 with value: 0.9944444444444445.
# [I 2025-03-03 22:33:39,304] Trial 499 finished with value: 0.9833333333333333 and parameters: {'ref_cells': 98, 'guard_cells': 92, 'far': 0.002519190401992397, 'margin': 1.3655971749649713}. Best is trial 94 with value: 0.9944444444444445.
# Meilleurs paramètres : {'ref_cells': 100, 'guard_cells': 94, 'far': 0.002308384445260484, 'margin': 1.3418950043440918}
# Meilleure accuracy : 0.99444

# %%
# Apply the CA-CFAR model with the best parameters and visualize the results
generated_data_cfar_optuna = ca_cfar(generated_data.copy(), **results["best_params"])

# Visualize the results
visualize_cfar_results(generated_data_cfar_optuna, title="CA-CFAR Anomaly Detection Results (Optuna)")

# %% [markdown]
# # Test and Train Set

# %%
def train_test_cafar(data, n_trials=300, test_size=0.2, random_state=42):
    """
    Split the dataset into train and test sets, optimize CA-CFAR parameters on the train set, 
    and evaluate on the test set.

    Parameters:
        data (DataFrame): The dataset containing 'kpi' and 'anomaly_true' columns.
        n_trials (int): Number of trials for the optimization.
        test_size (float): Fraction of the data to be used for testing.
        random_state (int): Seed for reproducibility.

    Returns:
        dict: Results including best parameters, train accuracy, and test accuracy.
    """
    # Split the dataset into train and test sets
    train_data, test_data = train_test_split(data, test_size=test_size, random_state=random_state)

    # Optimize parameters using Optuna on the train set
    def objective(trial):
        ref_cells = trial.suggest_int("ref_cells", 0, 100)
        guard_cells = trial.suggest_int("guard_cells", 0, 100)
        far = trial.suggest_float("far", 0.0005, 0.01)
        margin = trial.suggest_float("margin", 1.0, 2.0)
        
        train_cfar = ca_cfar(train_data.copy(), ref_cells=ref_cells, guard_cells=guard_cells, far=far, margin=margin)
        correct_predictions = (train_cfar['anomaly_true'] == train_cfar['anomaly']).sum()
        total_predictions = len(train_cfar)
        return correct_predictions / total_predictions

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials, callbacks=[lambda study, trial: study.stop() if study.best_value == 1.0 else None])

    best_params = study.best_params
    best_train_accuracy = study.best_value

    # Evaluate on the test set using the best parameters
    test_cfar = ca_cfar(test_data.copy(), **best_params)
    correct_predictions_test = (test_cfar['anomaly_true'] == test_cfar['anomaly']).sum()
    total_predictions_test = len(test_cfar)
    test_accuracy = correct_predictions_test / total_predictions_test

    return {
        "best_params": best_params,
        "best_train_accuracy": best_train_accuracy,
        "test_accuracy": test_accuracy,
        "train_data": train_data,
        "test_data": test_cfar
    }

def visualize_cfar_results_fixed(data, title="CA-CFAR Anomaly Detection Results"):
    """
    Visualizes KPI values, dynamic thresholds, and anomalies with enhanced readability.

    Parameters:
        data (DataFrame): DataFrame with 'timestamp', 'kpi', 'threshold', and 'anomaly' columns.
        title (str): Title for the plot.
    """
    # Ensure the data is sorted by timestamp
    data = data.sort_values(by="timestamp")

    # Extract anomalies
    anomalies = data[data['anomaly'] == 1]

    # Create the main line plot for KPI values
    fig = go.Figure()

    # Add KPI line plot
    fig.add_trace(go.Scatter(
        x=data['timestamp'],
        y=data['kpi'],
        mode='lines',
        name='KPI',
        line=dict(color='blue', width=1),
        opacity=0.8  # Add transparency to reduce clutter
    ))

    # Add anomalies as scatter points
    fig.add_trace(go.Scatter(
        x=anomalies['timestamp'],
        y=anomalies['kpi'],
        mode='markers',
        name='Anomalies',
        marker=dict(color='red', size=8, symbol='circle'),
        hoverinfo='x+y'
    ))

    # Add dynamic threshold plot
    fig.add_trace(go.Scatter(
        x=data['timestamp'],
        y=data['threshold'],
        mode='lines',
        name='Dynamic Threshold',
        line=dict(color='green', width=2, dash='dash')
    ))

    # Update layout for better visualization
    fig.update_layout(
        title=title,
        xaxis_title='Time',
        yaxis_title='KPI Value',
        yaxis=dict(range=[data['kpi'].min() - 0.1, data['kpi'].max() + 0.1]),  # Adjust y-axis
        legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1),
        template='plotly_white'
    )

    # Show the plot
    fig.show()

# %%
# Execute the train-test CA-CFAR process
results_split = train_test_cafar(generated_data, n_trials=300)

# Display results
print("Meilleurs paramètres :", results_split["best_params"])
print(f"Accuracy sur l'ensemble d'entraînement : {results_split['best_train_accuracy']:.5f}")
print(f"Accuracy sur l'ensemble de test : {results_split['test_accuracy']:.5f}")

# Visualize the test results
visualize_cfar_results_fixed(results_split["test_data"], title="CA-CFAR Test Set Results")
# Out:
# [I 2025-03-03 22:33:57,424] A new study created in memory with name: no-name-a1843c55-b9ee-4d67-b3d0-6fdbfb629aa3
# [I 2025-03-03 22:33:57,436] Trial 0 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 43, 'guard_cells': 83, 'far': 0.005849633779940218, 'margin': 1.3615216991039443}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,446] Trial 1 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 85, 'guard_cells': 68, 'far': 0.004614365454535255, 'margin': 1.5007407536304456}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,457] Trial 2 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 45, 'guard_cells': 93, 'far': 0.0011487285546796684, 'margin': 1.7319498634559163}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,466] Trial 3 finished with value: 0.9288194444444444 and parameters: {'ref_cells': 1, 'guard_cells': 97, 'far': 0.009607505118349735, 'margin': 1.8563222428175983}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,475] Trial 4 finished with value: 0.9305555555555556 and parameters: {'ref_cells': 16, 'guard_cells': 37, 'far': 0.006809223104011887, 'margin': 1.258056598114506}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,485] Trial 5 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 94, 'guard_cells': 71, 'far': 0.007932940504214489, 'margin': 1.7301667660925668}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,494] Trial 6 finished with value: 0.8932291666666666 and parameters: {'ref_cells': 83, 'guard_cells': 16, 'far': 0.00985904053274857, 'margin': 1.24433645814907}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,502] Trial 7 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 21, 'guard_cells': 21, 'far': 0.0016132896826836207, 'margin': 1.7023542142795391}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,511] Trial 8 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 43, 'guard_cells': 38, 'far': 0.004819910001018671, 'margin': 1.7203132872388056}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,520] Trial 9 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 96, 'guard_cells': 72, 'far': 0.0007726819583496862, 'margin': 1.6402688471801898}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,539] Trial 10 finished with value: 0.6215277777777778 and parameters: {'ref_cells': 73, 'guard_cells': 58, 'far': 0.003523880048932906, 'margin': 1.0277772351290477}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,557] Trial 11 finished with value: 0.9487847222222222 and parameters: {'ref_cells': 63, 'guard_cells': 78, 'far': 0.005300504293914544, 'margin': 1.4266042395790897}. Best is trial 0 with value: 0.9722222222222222.
# [I 2025-03-03 22:33:57,576] Trial 12 finished with value: 0.9782986111111112 and parameters: {'ref_cells': 60, 'guard_cells': 84, 'far': 0.0066751612390854795, 'margin': 1.3446835435148528}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,597] Trial 13 finished with value: 0.9635416666666666 and parameters: {'ref_cells': 61, 'guard_cells': 87, 'far': 0.007035206946392539, 'margin': 1.305203797851704}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,618] Trial 14 finished with value: 0.6744791666666666 and parameters: {'ref_cells': 34, 'guard_cells': 54, 'far': 0.006276694748157869, 'margin': 1.0721574004050458}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,638] Trial 15 finished with value: 0.9401041666666666 and parameters: {'ref_cells': 58, 'guard_cells': 2, 'far': 0.00845350550454678, 'margin': 1.4405853831434925}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,665] Trial 16 finished with value: 0.7786458333333334 and parameters: {'ref_cells': 32, 'guard_cells': 86, 'far': 0.002645016271706274, 'margin': 1.1586017961315185}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,688] Trial 17 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 52, 'guard_cells': 100, 'far': 0.00600284477720557, 'margin': 1.5477566941855951}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,713] Trial 18 finished with value: 0.9739583333333334 and parameters: {'ref_cells': 71, 'guard_cells': 60, 'far': 0.003960657768185222, 'margin': 1.3673285215318942}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,732] Trial 19 finished with value: 0.7699652777777778 and parameters: {'ref_cells': 72, 'guard_cells': 45, 'far': 0.0038744907798965627, 'margin': 1.1638418718864585}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,751] Trial 20 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 71, 'guard_cells': 62, 'far': 0.003021163092024473, 'margin': 1.9552739355589457}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,772] Trial 21 finished with value: 0.9704861111111112 and parameters: {'ref_cells': 52, 'guard_cells': 81, 'far': 0.005483702561923953, 'margin': 1.3623849617116734}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,791] Trial 22 finished with value: 0.9600694444444444 and parameters: {'ref_cells': 38, 'guard_cells': 78, 'far': 0.007514736413028468, 'margin': 1.3777135562133682}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,810] Trial 23 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 82, 'guard_cells': 66, 'far': 0.004273793665116796, 'margin': 1.5688915433033574}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,828] Trial 24 finished with value: 0.8133680555555556 and parameters: {'ref_cells': 65, 'guard_cells': 45, 'far': 0.002298296301740909, 'margin': 1.1946372435523895}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,847] Trial 25 finished with value: 0.9609375 and parameters: {'ref_cells': 27, 'guard_cells': 86, 'far': 0.008780106942454034, 'margin': 1.3528289597362264}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,867] Trial 26 finished with value: 0.9366319444444444 and parameters: {'ref_cells': 54, 'guard_cells': 93, 'far': 0.005932861753449136, 'margin': 1.461920104127183}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,888] Trial 27 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 43, 'guard_cells': 75, 'far': 0.006676932570570447, 'margin': 1.3088606283006357}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,909] Trial 28 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 76, 'guard_cells': 57, 'far': 0.005105474453098648, 'margin': 1.565673227598936}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,930] Trial 29 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 91, 'guard_cells': 68, 'far': 0.004284799246932349, 'margin': 1.5089393103542488}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,959] Trial 30 finished with value: 0.8793402777777778 and parameters: {'ref_cells': 66, 'guard_cells': 64, 'far': 0.0034954728680244643, 'margin': 1.2491129862515158}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:57,987] Trial 31 finished with value: 0.9626736111111112 and parameters: {'ref_cells': 52, 'guard_cells': 84, 'far': 0.005484380380506336, 'margin': 1.3840522070730104}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,009] Trial 32 finished with value: 0.9765625 and parameters: {'ref_cells': 47, 'guard_cells': 80, 'far': 0.005742710163868338, 'margin': 1.342814346832988}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,030] Trial 33 finished with value: 0.7196180555555556 and parameters: {'ref_cells': 46, 'guard_cells': 93, 'far': 0.007557624060312528, 'margin': 1.1042102660245348}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,047] Trial 34 finished with value: 0.9565972222222222 and parameters: {'ref_cells': 58, 'guard_cells': 94, 'far': 0.004505364954859875, 'margin': 1.3008645945171913}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,067] Trial 35 finished with value: 0.9366319444444444 and parameters: {'ref_cells': 9, 'guard_cells': 90, 'far': 0.006609258467724231, 'margin': 1.4967511344836808}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,085] Trial 36 finished with value: 0.8697916666666666 and parameters: {'ref_cells': 46, 'guard_cells': 73, 'far': 0.005738770263036365, 'margin': 1.2364904194069248}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,103] Trial 37 finished with value: 0.9461805555555556 and parameters: {'ref_cells': 38, 'guard_cells': 79, 'far': 0.007204498770175391, 'margin': 1.4155421679978355}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,124] Trial 38 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 78, 'guard_cells': 27, 'far': 0.004874241676959536, 'margin': 1.3080181477069142}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,144] Trial 39 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 86, 'guard_cells': 47, 'far': 0.008427289342928112, 'margin': 1.6593759260780254}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,163] Trial 40 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 24, 'guard_cells': 99, 'far': 0.0018147540378634615, 'margin': 1.8420895638905925}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,183] Trial 41 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 56, 'guard_cells': 82, 'far': 0.006304315819012994, 'margin': 1.3481455266665796}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,202] Trial 42 finished with value: 0.9739583333333334 and parameters: {'ref_cells': 59, 'guard_cells': 70, 'far': 0.006398125443553572, 'margin': 1.357085933284978}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,223] Trial 43 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 67, 'guard_cells': 70, 'far': 0.0063654670996595815, 'margin': 1.4825922565235254}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,243] Trial 44 finished with value: 0.9210069444444444 and parameters: {'ref_cells': 46, 'guard_cells': 61, 'far': 0.007066438199767424, 'margin': 1.2732269073539555}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,264] Trial 45 finished with value: 0.9600694444444444 and parameters: {'ref_cells': 61, 'guard_cells': 75, 'far': 0.004868985634408468, 'margin': 1.411970052201524}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,286] Trial 46 finished with value: 0.8611111111111112 and parameters: {'ref_cells': 37, 'guard_cells': 52, 'far': 0.007894136661393011, 'margin': 1.2216034068816823}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,308] Trial 47 finished with value: 0.9704861111111112 and parameters: {'ref_cells': 48, 'guard_cells': 70, 'far': 0.003821668935441584, 'margin': 1.3295588321765146}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,332] Trial 48 finished with value: 0.9574652777777778 and parameters: {'ref_cells': 68, 'guard_cells': 39, 'far': 0.009273506071069125, 'margin': 1.3972099057926637}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,354] Trial 49 finished with value: 0.734375 and parameters: {'ref_cells': 60, 'guard_cells': 58, 'far': 0.005727555082257393, 'margin': 1.1296119759778032}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,376] Trial 50 finished with value: 0.9401041666666666 and parameters: {'ref_cells': 41, 'guard_cells': 89, 'far': 0.006635616354838821, 'margin': 1.4475337943302504}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,398] Trial 51 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 55, 'guard_cells': 82, 'far': 0.0062805497435189424, 'margin': 1.347035391358201}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,421] Trial 52 finished with value: 0.9288194444444444 and parameters: {'ref_cells': 56, 'guard_cells': 77, 'far': 0.006149358020689106, 'margin': 1.2800288337821313}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,439] Trial 53 finished with value: 0.8394097222222222 and parameters: {'ref_cells': 49, 'guard_cells': 83, 'far': 0.005262043476861034, 'margin': 1.2062224989923798}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,461] Trial 54 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 64, 'guard_cells': 67, 'far': 0.0075678239662178536, 'margin': 1.5260845796757765}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,481] Trial 55 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 30, 'guard_cells': 73, 'far': 0.006936940756379566, 'margin': 1.3384114550908626}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,502] Trial 56 finished with value: 0.96875 and parameters: {'ref_cells': 70, 'guard_cells': 80, 'far': 0.0059657957710589175, 'margin': 1.3761240379366568}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,521] Trial 57 finished with value: 0.9427083333333334 and parameters: {'ref_cells': 58, 'guard_cells': 88, 'far': 0.005557932570861862, 'margin': 1.4405293691411394}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,542] Trial 58 finished with value: 0.8090277777777778 and parameters: {'ref_cells': 75, 'guard_cells': 96, 'far': 0.004558517678125283, 'margin': 1.1865273139673869}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,565] Trial 59 finished with value: 0.9131944444444444 and parameters: {'ref_cells': 41, 'guard_cells': 64, 'far': 0.005231563394778723, 'margin': 1.273283746998567}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,585] Trial 60 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 63, 'guard_cells': 85, 'far': 0.006428205610316237, 'margin': 1.6070327905551893}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,610] Trial 61 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 54, 'guard_cells': 82, 'far': 0.0062096592224210045, 'margin': 1.3411895419514006}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,628] Trial 62 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 51, 'guard_cells': 76, 'far': 0.00720468562354711, 'margin': 1.3286080505867386}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,647] Trial 63 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 51, 'guard_cells': 76, 'far': 0.007843102142311318, 'margin': 1.47263524578934}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,665] Trial 64 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 50, 'guard_cells': 73, 'far': 0.007231949873491085, 'margin': 1.320098402914997}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,685] Trial 65 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 53, 'guard_cells': 71, 'far': 0.007193816427574805, 'margin': 1.3132507395806126}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,706] Trial 66 finished with value: 0.9618055555555556 and parameters: {'ref_cells': 61, 'guard_cells': 60, 'far': 0.008293485440426513, 'margin': 1.3978933002819427}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,727] Trial 67 finished with value: 0.9296875 and parameters: {'ref_cells': 49, 'guard_cells': 65, 'far': 0.007428965156882248, 'margin': 1.2820501712146612}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,748] Trial 68 finished with value: 0.8854166666666666 and parameters: {'ref_cells': 79, 'guard_cells': 79, 'far': 0.006719468938981331, 'margin': 1.2407274260272205}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,769] Trial 69 finished with value: 0.96875 and parameters: {'ref_cells': 69, 'guard_cells': 56, 'far': 0.007320062896167882, 'margin': 1.3821996921777415}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,792] Trial 70 finished with value: 0.7934027777777778 and parameters: {'ref_cells': 43, 'guard_cells': 91, 'far': 0.008133002188896642, 'margin': 1.1672674308709934}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,816] Trial 71 finished with value: 0.9461805555555556 and parameters: {'ref_cells': 34, 'guard_cells': 76, 'far': 0.005853932261145789, 'margin': 1.4288985215724477}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,837] Trial 72 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 50, 'guard_cells': 85, 'far': 0.006896825205160887, 'margin': 1.322807358190596}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,861] Trial 73 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 58, 'guard_cells': 86, 'far': 0.006939822977775562, 'margin': 1.3244619587723871}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,892] Trial 74 finished with value: 0.9713541666666666 and parameters: {'ref_cells': 59, 'guard_cells': 86, 'far': 0.006872039034666043, 'margin': 1.3659222620653435}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,922] Trial 75 finished with value: 0.9609375 and parameters: {'ref_cells': 53, 'guard_cells': 92, 'far': 0.008734994356905728, 'margin': 1.301330294405579}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,945] Trial 76 finished with value: 0.9071180555555556 and parameters: {'ref_cells': 65, 'guard_cells': 88, 'far': 0.007681964885420818, 'margin': 1.2554759620070632}. Best is trial 12 with value: 0.9782986111111112.
# [I 2025-03-03 22:33:58,963] Trial 77 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 57, 'guard_cells': 96, 'far': 0.006519457755629037, 'margin': 1.3635050354284421}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:58,983] Trial 78 finished with value: 0.9505208333333334 and parameters: {'ref_cells': 62, 'guard_cells': 96, 'far': 0.006473201587378041, 'margin': 1.4115555969962377}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,002] Trial 79 finished with value: 0.6102430555555556 and parameters: {'ref_cells': 72, 'guard_cells': 100, 'far': 0.002978048432632701, 'margin': 1.0135010863649594}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,025] Trial 80 finished with value: 0.9375 and parameters: {'ref_cells': 56, 'guard_cells': 68, 'far': 0.006733287835102372, 'margin': 1.4603200301665922}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,046] Trial 81 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 47, 'guard_cells': 84, 'far': 0.006054959208715777, 'margin': 1.3595063222623351}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,066] Trial 82 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 46, 'guard_cells': 85, 'far': 0.00606858585946185, 'margin': 1.3611535641067962}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,089] Trial 83 finished with value: 0.953125 and parameters: {'ref_cells': 45, 'guard_cells': 94, 'far': 0.0056386105575065015, 'margin': 1.2946284839823057}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,111] Trial 84 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 41, 'guard_cells': 84, 'far': 0.007033384861295254, 'margin': 1.3761254350569792}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,134] Trial 85 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 48, 'guard_cells': 89, 'far': 0.005992805351346335, 'margin': 1.3308395044213972}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,155] Trial 86 finished with value: 0.9670138888888888 and parameters: {'ref_cells': 37, 'guard_cells': 97, 'far': 0.006068645501221993, 'margin': 1.3274353534343122}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,180] Trial 87 finished with value: 0.921875 and parameters: {'ref_cells': 46, 'guard_cells': 89, 'far': 0.005415512160652775, 'margin': 1.2682013036630342}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,207] Trial 88 finished with value: 0.8550347222222222 and parameters: {'ref_cells': 48, 'guard_cells': 91, 'far': 0.005864078125687099, 'margin': 1.2209038230472111}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,223] Trial 89 finished with value: 0.06510416666666667 and parameters: {'ref_cells': 0, 'guard_cells': 85, 'far': 0.0065737666170085874, 'margin': 1.4013530313461}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,246] Trial 90 finished with value: 0.9418402777777778 and parameters: {'ref_cells': 44, 'guard_cells': 13, 'far': 0.006934744854438559, 'margin': 1.4275929025217207}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,264] Trial 91 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 51, 'guard_cells': 87, 'far': 0.005103188290787205, 'margin': 1.3585690323611583}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,286] Trial 92 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 47, 'guard_cells': 79, 'far': 0.006105839477408474, 'margin': 1.3242826918328956}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,305] Trial 93 finished with value: 0.9470486111111112 and parameters: {'ref_cells': 40, 'guard_cells': 94, 'far': 0.006780125539464829, 'margin': 1.288458240604512}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,328] Trial 94 finished with value: 0.9635416666666666 and parameters: {'ref_cells': 57, 'guard_cells': 81, 'far': 0.0050084304840805685, 'margin': 1.3856407747237665}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,347] Trial 95 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 50, 'guard_cells': 90, 'far': 0.004265360653718091, 'margin': 1.3441413241115612}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,368] Trial 96 finished with value: 0.9131944444444444 and parameters: {'ref_cells': 54, 'guard_cells': 98, 'far': 0.005813493045736551, 'margin': 1.2595964560063186}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,389] Trial 97 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 44, 'guard_cells': 84, 'far': 0.0064843921622912415, 'margin': 1.3597324799574628}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,411] Trial 98 finished with value: 0.8836805555555556 and parameters: {'ref_cells': 39, 'guard_cells': 84, 'far': 0.0064910933505702454, 'margin': 1.2351167906877742}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,430] Trial 99 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 43, 'guard_cells': 86, 'far': 0.006201666470371439, 'margin': 1.9825513002707296}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,454] Trial 100 finished with value: 0.9583333333333334 and parameters: {'ref_cells': 33, 'guard_cells': 81, 'far': 0.00709790335761087, 'margin': 1.3181626584464654}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,476] Trial 101 finished with value: 0.9782986111111112 and parameters: {'ref_cells': 48, 'guard_cells': 78, 'far': 0.00561043469643833, 'margin': 1.3532797308027562}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,496] Trial 102 finished with value: 0.9713541666666666 and parameters: {'ref_cells': 51, 'guard_cells': 78, 'far': 0.0055880206756685515, 'margin': 1.3670006088254762}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,518] Trial 103 finished with value: 0.9401041666666666 and parameters: {'ref_cells': 48, 'guard_cells': 88, 'far': 0.0059832782269093835, 'margin': 1.4503813075202139}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,537] Trial 104 finished with value: 0.9809027777777778 and parameters: {'ref_cells': 43, 'guard_cells': 83, 'far': 0.005395504434565769, 'margin': 1.3385460356898875}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,557] Trial 105 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 36, 'guard_cells': 75, 'far': 0.005458365335289532, 'margin': 1.3025080122702808}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,580] Trial 106 finished with value: 0.9557291666666666 and parameters: {'ref_cells': 42, 'guard_cells': 92, 'far': 0.0056863872641564756, 'margin': 1.39950048724915}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,601] Trial 107 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 55, 'guard_cells': 83, 'far': 0.0005438405949632517, 'margin': 1.3358924306548443}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,620] Trial 108 finished with value: 0.9565972222222222 and parameters: {'ref_cells': 55, 'guard_cells': 77, 'far': 0.0012257331057863826, 'margin': 1.420060374337946}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,681] Trial 109 finished with value: 0.9782986111111112 and parameters: {'ref_cells': 60, 'guard_cells': 83, 'far': 0.00530518639084903, 'margin': 1.343763316091052}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,702] Trial 110 finished with value: 0.9357638888888888 and parameters: {'ref_cells': 53, 'guard_cells': 82, 'far': 0.00525956551700434, 'margin': 1.4827243427336176}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,722] Trial 111 finished with value: 0.9765625 and parameters: {'ref_cells': 59, 'guard_cells': 80, 'far': 0.004757949541233933, 'margin': 1.336642671942011}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,744] Trial 112 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 60, 'guard_cells': 80, 'far': 0.004708634671398227, 'margin': 1.3430164424762001}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,763] Trial 113 finished with value: 0.9661458333333334 and parameters: {'ref_cells': 61, 'guard_cells': 79, 'far': 0.004609488071964078, 'margin': 1.3864034223300674}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,784] Trial 114 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 67, 'guard_cells': 80, 'far': 0.0005972134708501656, 'margin': 1.3486405491993458}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,807] Trial 115 finished with value: 0.9279513888888888 and parameters: {'ref_cells': 67, 'guard_cells': 74, 'far': 0.0007044816402248729, 'margin': 1.2871918334656915}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,830] Trial 116 finished with value: 0.9505208333333334 and parameters: {'ref_cells': 64, 'guard_cells': 81, 'far': 0.0009213050313823828, 'margin': 1.3048559901241814}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,861] Trial 117 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 60, 'guard_cells': 72, 'far': 0.0017590457214724108, 'margin': 1.3357830965063187}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,886] Trial 118 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 62, 'guard_cells': 80, 'far': 0.001143451277864515, 'margin': 1.8785702025893274}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,907] Trial 119 finished with value: 0.9765625 and parameters: {'ref_cells': 58, 'guard_cells': 77, 'far': 0.004729252429260261, 'margin': 1.3442417838230918}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,929] Trial 120 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 65, 'guard_cells': 77, 'far': 0.004712184439989876, 'margin': 1.3485429534134228}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,948] Trial 121 finished with value: 0.9696180555555556 and parameters: {'ref_cells': 58, 'guard_cells': 83, 'far': 0.004918252896501333, 'margin': 1.3770955878382742}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,972] Trial 122 finished with value: 0.9262152777777778 and parameters: {'ref_cells': 56, 'guard_cells': 83, 'far': 0.004261902642523899, 'margin': 1.2753072181893166}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:33:59,992] Trial 123 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 63, 'guard_cells': 78, 'far': 0.004459581020700929, 'margin': 1.3487108612893464}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,015] Trial 124 finished with value: 0.9626736111111112 and parameters: {'ref_cells': 68, 'guard_cells': 74, 'far': 0.003628595969805112, 'margin': 1.4026759703736638}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,040] Trial 125 finished with value: 0.9470486111111112 and parameters: {'ref_cells': 63, 'guard_cells': 79, 'far': 0.0020861181865279932, 'margin': 1.4364806845544102}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,065] Trial 126 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 59, 'guard_cells': 70, 'far': 0.004109045804122346, 'margin': 1.3413369001400728}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,087] Trial 127 finished with value: 0.9557291666666666 and parameters: {'ref_cells': 74, 'guard_cells': 70, 'far': 0.00515840061812649, 'margin': 1.307259542635273}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,108] Trial 128 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 61, 'guard_cells': 81, 'far': 0.004407649557433569, 'margin': 1.3875343323144613}. Best is trial 77 with value: 0.9826388888888888.
# [I 2025-03-03 22:34:00,130] Trial 129 finished with value: 0.9835069444444444 and parameters: {'ref_cells': 65, 'guard_cells': 30, 'far': 0.0005691447111597204, 'margin': 1.363133581425047}. Best is trial 129 with value: 0.9835069444444444.
# [I 2025-03-03 22:34:00,152] Trial 130 finished with value: 0.9539930555555556 and parameters: {'ref_cells': 69, 'guard_cells': 28, 'far': 0.0005836265197147236, 'margin': 1.4143762402720084}. Best is trial 129 with value: 0.9835069444444444.
# [I 2025-03-03 22:34:00,176] Trial 131 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 65, 'guard_cells': 40, 'far': 0.0041133592110175555, 'margin': 1.3613643624414984}. Best is trial 129 with value: 0.9835069444444444.
# [I 2025-03-03 22:34:00,199] Trial 132 finished with value: 0.9765625 and parameters: {'ref_cells': 71, 'guard_cells': 40, 'far': 0.003943041403993499, 'margin': 1.3650926298379065}. Best is trial 129 with value: 0.9835069444444444.
# [I 2025-03-03 22:34:00,221] Trial 133 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 66, 'guard_cells': 31, 'far': 0.0014441335714292143, 'margin': 1.3541292307321933}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,243] Trial 134 finished with value: 0.9852430555555556 and parameters: {'ref_cells': 66, 'guard_cells': 31, 'far': 0.0014862163368430789, 'margin': 1.3557546155513664}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,266] Trial 135 finished with value: 0.9696180555555556 and parameters: {'ref_cells': 66, 'guard_cells': 32, 'far': 0.001261206880206258, 'margin': 1.3850306496683484}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,287] Trial 136 finished with value: 0.9418402777777778 and parameters: {'ref_cells': 66, 'guard_cells': 21, 'far': 0.0010228189974212005, 'margin': 1.2925756715234586}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,308] Trial 137 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 64, 'guard_cells': 32, 'far': 0.0008149618197633217, 'margin': 1.3618415983061904}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,331] Trial 138 finished with value: 0.9765625 and parameters: {'ref_cells': 77, 'guard_cells': 35, 'far': 0.0015748136956284615, 'margin': 1.3690762342067355}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,352] Trial 139 finished with value: 0.9513888888888888 and parameters: {'ref_cells': 64, 'guard_cells': 28, 'far': 0.0012930900499690786, 'margin': 1.4197444331726206}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,374] Trial 140 finished with value: 0.9548611111111112 and parameters: {'ref_cells': 15, 'guard_cells': 31, 'far': 0.0009128057988922666, 'margin': 1.314848832967093}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,399] Trial 141 finished with value: 0.9852430555555556 and parameters: {'ref_cells': 70, 'guard_cells': 25, 'far': 0.0014121423141257017, 'margin': 1.3517321913606049}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,426] Trial 142 finished with value: 0.984375 and parameters: {'ref_cells': 70, 'guard_cells': 21, 'far': 0.002424930383910337, 'margin': 1.3691915486031394}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,461] Trial 143 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 73, 'guard_cells': 23, 'far': 0.0014939349554137415, 'margin': 1.399939727438567}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,493] Trial 144 finished with value: 0.9835069444444444 and parameters: {'ref_cells': 70, 'guard_cells': 26, 'far': 0.0027262810304507215, 'margin': 1.3676792006030736}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,513] Trial 145 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 100, 'guard_cells': 23, 'far': 0.0025095148145843917, 'margin': 1.3768373014475264}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,534] Trial 146 finished with value: 0.9418402777777778 and parameters: {'ref_cells': 83, 'guard_cells': 24, 'far': 0.0024457111535334513, 'margin': 1.4378524379424586}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,556] Trial 147 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 88, 'guard_cells': 20, 'far': 0.0027942622198342446, 'margin': 1.3681968219376222}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,581] Trial 148 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 96, 'guard_cells': 26, 'far': 0.0029103102310573574, 'margin': 1.3784921169787143}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,604] Trial 149 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 98, 'guard_cells': 17, 'far': 0.003308719947620842, 'margin': 1.373009534271983}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,628] Trial 150 finished with value: 0.9357638888888888 and parameters: {'ref_cells': 99, 'guard_cells': 16, 'far': 0.003223827718503343, 'margin': 1.4655643311192994}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,651] Trial 151 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 91, 'guard_cells': 19, 'far': 0.0027587548558153357, 'margin': 1.367898202520878}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,675] Trial 152 finished with value: 0.9574652777777778 and parameters: {'ref_cells': 89, 'guard_cells': 18, 'far': 0.0026819590439353946, 'margin': 1.4075622333567457}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,697] Trial 153 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 100, 'guard_cells': 10, 'far': 0.002225335726203684, 'margin': 1.374282782406463}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,720] Trial 154 finished with value: 0.96875 and parameters: {'ref_cells': 100, 'guard_cells': 12, 'far': 0.0020527771934440962, 'margin': 1.3928361848137822}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,742] Trial 155 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 94, 'guard_cells': 9, 'far': 0.0027437308900360798, 'margin': 1.370345867683755}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,764] Trial 156 finished with value: 0.9487847222222222 and parameters: {'ref_cells': 93, 'guard_cells': 8, 'far': 0.0026401421089985513, 'margin': 1.4245891859159856}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,788] Trial 157 finished with value: 0.9835069444444444 and parameters: {'ref_cells': 97, 'guard_cells': 17, 'far': 0.002297106152810889, 'margin': 1.3724615040017705}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,811] Trial 158 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 97, 'guard_cells': 21, 'far': 0.0022645203858815527, 'margin': 1.381124999732298}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,833] Trial 159 finished with value: 0.9592013888888888 and parameters: {'ref_cells': 89, 'guard_cells': 5, 'far': 0.003183293414873848, 'margin': 1.4097914964813156}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,860] Trial 160 finished with value: 0.9348958333333334 and parameters: {'ref_cells': 94, 'guard_cells': 19, 'far': 0.002474372812062483, 'margin': 1.5120844889873277}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,884] Trial 161 finished with value: 0.984375 and parameters: {'ref_cells': 92, 'guard_cells': 12, 'far': 0.001972828404229833, 'margin': 1.3616321707209336}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,915] Trial 162 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 92, 'guard_cells': 13, 'far': 0.001962319597911099, 'margin': 1.3689864305957977}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,938] Trial 163 finished with value: 0.9644097222222222 and parameters: {'ref_cells': 91, 'guard_cells': 15, 'far': 0.0018320064521523153, 'margin': 1.3137919043465036}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,963] Trial 164 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 94, 'guard_cells': 18, 'far': 0.0019489978361595915, 'margin': 1.3976790748251149}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:00,991] Trial 165 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 98, 'guard_cells': 30, 'far': 0.002555319402290556, 'margin': 1.369136320535322}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,015] Trial 166 finished with value: 0.9392361111111112 and parameters: {'ref_cells': 86, 'guard_cells': 25, 'far': 0.0028725401448528288, 'margin': 1.440077413489583}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,066] Trial 167 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 92, 'guard_cells': 22, 'far': 0.002812533639992171, 'margin': 1.3265194366282183}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,093] Trial 168 finished with value: 0.9809027777777778 and parameters: {'ref_cells': 97, 'guard_cells': 34, 'far': 0.0014529508732322293, 'margin': 1.3684852047649863}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,114] Trial 169 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 89, 'guard_cells': 35, 'far': 0.001458704601829329, 'margin': 1.3856458062659303}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,135] Trial 170 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 96, 'guard_cells': 33, 'far': 0.001699458202183336, 'margin': 1.3597398552417244}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,157] Trial 171 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 95, 'guard_cells': 34, 'far': 0.001740804833515017, 'margin': 1.35293256191795}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,180] Trial 172 finished with value: 0.9678819444444444 and parameters: {'ref_cells': 96, 'guard_cells': 33, 'far': 0.001669785434934621, 'margin': 1.3212570360890008}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,200] Trial 173 finished with value: 0.9809027777777778 and parameters: {'ref_cells': 95, 'guard_cells': 29, 'far': 0.0018869245278330883, 'margin': 1.35714665838824}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,230] Trial 174 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 96, 'guard_cells': 29, 'far': 0.0018331039238093513, 'margin': 1.3526668216614988}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,259] Trial 175 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 97, 'guard_cells': 37, 'far': 0.0021221053458489536, 'margin': 1.3267805865268896}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,285] Trial 176 finished with value: 0.9704861111111112 and parameters: {'ref_cells': 93, 'guard_cells': 33, 'far': 0.0014444346960862246, 'margin': 1.395431353810897}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,311] Trial 177 finished with value: 0.9392361111111112 and parameters: {'ref_cells': 98, 'guard_cells': 13, 'far': 0.001664576584744716, 'margin': 1.298290090206909}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,334] Trial 178 finished with value: 0.984375 and parameters: {'ref_cells': 96, 'guard_cells': 27, 'far': 0.0019552113487627453, 'margin': 1.3528242389917293}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,354] Trial 179 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 95, 'guard_cells': 26, 'far': 0.002370159632999109, 'margin': 1.3394161922634793}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,377] Trial 180 finished with value: 0.6597222222222222 and parameters: {'ref_cells': 94, 'guard_cells': 26, 'far': 0.00232993733816352, 'margin': 1.0663376357711551}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,400] Trial 181 finished with value: 0.9835069444444444 and parameters: {'ref_cells': 80, 'guard_cells': 30, 'far': 0.0019104799257595555, 'margin': 1.3473565974043418}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,426] Trial 182 finished with value: 0.9852430555555556 and parameters: {'ref_cells': 70, 'guard_cells': 30, 'far': 0.0019806318265574354, 'margin': 1.3511590654797534}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,448] Trial 183 finished with value: 0.9661458333333334 and parameters: {'ref_cells': 79, 'guard_cells': 27, 'far': 0.0019965407864507, 'margin': 1.31425442807878}. Best is trial 133 with value: 0.9861111111111112.
# [I 2025-03-03 22:34:01,476] Trial 184 finished with value: 0.9887152777777778 and parameters: {'ref_cells': 71, 'guard_cells': 15, 'far': 0.002310441828177308, 'margin': 1.3477027899151885}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,503] Trial 185 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 70, 'guard_cells': 16, 'far': 0.002290449814519994, 'margin': 1.3325041008784653}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,531] Trial 186 finished with value: 0.9574652777777778 and parameters: {'ref_cells': 72, 'guard_cells': 9, 'far': 0.002193928727824262, 'margin': 1.4161994459828038}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,556] Trial 187 finished with value: 0.96875 and parameters: {'ref_cells': 76, 'guard_cells': 31, 'far': 0.0007930668296852359, 'margin': 1.3912636222757582}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,580] Trial 188 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 70, 'guard_cells': 6, 'far': 0.0024069572969260683, 'margin': 1.3464395665283022}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,603] Trial 189 finished with value: 0.984375 and parameters: {'ref_cells': 70, 'guard_cells': 26, 'far': 0.002401073606954439, 'margin': 1.3442900993015607}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,629] Trial 190 finished with value: 0.9357638888888888 and parameters: {'ref_cells': 74, 'guard_cells': 24, 'far': 0.002473992593317154, 'margin': 1.2914910317134582}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,655] Trial 191 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 69, 'guard_cells': 4, 'far': 0.0031203529352531864, 'margin': 1.3392636006100649}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,677] Trial 192 finished with value: 0.9878472222222222 and parameters: {'ref_cells': 70, 'guard_cells': 2, 'far': 0.003045352811039858, 'margin': 1.3405145815457855}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,699] Trial 193 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 70, 'guard_cells': 2, 'far': 0.0023422941743951936, 'margin': 1.3386863138010798}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,719] Trial 194 finished with value: 0.9592013888888888 and parameters: {'ref_cells': 70, 'guard_cells': 0, 'far': 0.0020675790800366452, 'margin': 1.3112419195964158}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,742] Trial 195 finished with value: 0.9878472222222222 and parameters: {'ref_cells': 69, 'guard_cells': 3, 'far': 0.0010879791420573214, 'margin': 1.3492063111180064}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,766] Trial 196 finished with value: 0.9670138888888888 and parameters: {'ref_cells': 68, 'guard_cells': 4, 'far': 0.0010947795219585978, 'margin': 1.3184823187934434}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,785] Trial 197 finished with value: 0.9835069444444444 and parameters: {'ref_cells': 72, 'guard_cells': 3, 'far': 0.003089519960216558, 'margin': 1.3415113749255514}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,809] Trial 198 finished with value: 0.9210069444444444 and parameters: {'ref_cells': 72, 'guard_cells': 5, 'far': 0.0008042607257211041, 'margin': 1.2754713737756165}. Best is trial 184 with value: 0.9887152777777778.
# [I 2025-03-03 22:34:01,831] Trial 199 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 69, 'guard_cells': 0, 'far': 0.0034399962651319722, 'margin': 1.3279734695494116}. Best is trial 184 with value: 0.9887152777777778.
# ...
# [I 2025-03-03 22:34:02,840] Trial 232 finished with value: 0.984375 and parameters: {'ref_cells': 67, 'guard_cells': 7, 'far': 0.0034133187714080635, 'margin': 1.3538587085103073}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:02,872] Trial 233 finished with value: 0.9739583333333334 and parameters: {'ref_cells': 75, 'guard_cells': 11, 'far': 0.003025863544004895, 'margin': 1.319728121004525}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:02,901] Trial 234 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 69, 'guard_cells': 9, 'far': 0.0033559449823385573, 'margin': 1.3428910412395931}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:02,929] Trial 235 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 83, 'guard_cells': 10, 'far': 0.003303880076479796, 'margin': 1.3361174997599776}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:02,959] Trial 236 finished with value: 0.9878472222222222 and parameters: {'ref_cells': 72, 'guard_cells': 8, 'far': 0.00365935339965336, 'margin': 1.353769895828537}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:02,990] Trial 237 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 73, 'guard_cells': 8, 'far': 0.0037005207523112607, 'margin': 1.316207809526179}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,029] Trial 238 finished with value: 0.9722222222222222 and parameters: {'ref_cells': 72, 'guard_cells': 2, 'far': 0.003539260485248793, 'margin': 1.3822539358223447}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,061] Trial 239 finished with value: 0.9270833333333334 and parameters: {'ref_cells': 76, 'guard_cells': 5, 'far': 0.003845172436319433, 'margin': 1.2786390840945288}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,090] Trial 240 finished with value: 0.9887152777777778 and parameters: {'ref_cells': 68, 'guard_cells': 11, 'far': 0.003301046009912586, 'margin': 1.3382169988279602}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,117] Trial 241 finished with value: 0.9887152777777778 and parameters: {'ref_cells': 69, 'guard_cells': 11, 'far': 0.003335496131731688, 'margin': 1.3389066305524056}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,145] Trial 242 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 68, 'guard_cells': 12, 'far': 0.003090972737682228, 'margin': 1.3564524703677252}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,174] Trial 243 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 67, 'guard_cells': 11, 'far': 0.003012957653004008, 'margin': 1.3263866771655657}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,207] Trial 244 finished with value: 0.9887152777777778 and parameters: {'ref_cells': 69, 'guard_cells': 13, 'far': 0.003474534655232441, 'margin': 1.3581767631900874}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,234] Trial 245 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 72, 'guard_cells': 14, 'far': 0.0035827221185486457, 'margin': 1.3642412751126658}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,261] Trial 246 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 74, 'guard_cells': 12, 'far': 0.003451996109419834, 'margin': 1.3628620917034129}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,288] Trial 247 finished with value: 0.9739583333333334 and parameters: {'ref_cells': 68, 'guard_cells': 14, 'far': 0.00399422407878505, 'margin': 1.382856700495793}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,318] Trial 248 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 71, 'guard_cells': 10, 'far': 0.0037387785947403016, 'margin': 1.316653915252842}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,348] Trial 249 finished with value: 0.9852430555555556 and parameters: {'ref_cells': 66, 'guard_cells': 7, 'far': 0.0033078382964276828, 'margin': 1.3551429364205416}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,380] Trial 250 finished with value: 0.984375 and parameters: {'ref_cells': 69, 'guard_cells': 12, 'far': 0.0035907423865052944, 'margin': 1.3341112724011992}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,413] Trial 251 finished with value: 0.9652777777777778 and parameters: {'ref_cells': 73, 'guard_cells': 8, 'far': 0.0029950252121886574, 'margin': 1.3964227654005954}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,445] Trial 252 finished with value: 0.9704861111111112 and parameters: {'ref_cells': 71, 'guard_cells': 50, 'far': 0.0037852938244541455, 'margin': 1.3744965546656653}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,477] Trial 253 finished with value: 0.9592013888888888 and parameters: {'ref_cells': 64, 'guard_cells': 43, 'far': 0.004144017672448086, 'margin': 1.3136200925988182}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,504] Trial 254 finished with value: 0.9895833333333334 and parameters: {'ref_cells': 77, 'guard_cells': 11, 'far': 0.0034551042391905186, 'margin': 1.353539176856096}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,531] Trial 255 finished with value: 0.984375 and parameters: {'ref_cells': 77, 'guard_cells': 10, 'far': 0.003471457455045588, 'margin': 1.3397197814311435}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,556] Trial 256 finished with value: 0.9522569444444444 and parameters: {'ref_cells': 75, 'guard_cells': 15, 'far': 0.0032016913414888255, 'margin': 1.2988513975650116}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,583] Trial 257 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 79, 'guard_cells': 12, 'far': 0.003624549714301597, 'margin': 1.3524553897446199}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,609] Trial 258 finished with value: 0.9809027777777778 and parameters: {'ref_cells': 79, 'guard_cells': 12, 'far': 0.003626272472214793, 'margin': 1.3303527101551946}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,634] Trial 259 finished with value: 0.9765625 and parameters: {'ref_cells': 78, 'guard_cells': 0, 'far': 0.003351877455281987, 'margin': 1.3833173918706743}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,665] Trial 260 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 73, 'guard_cells': 9, 'far': 0.00388974181933805, 'margin': 1.3523252407402981}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,693] Trial 261 finished with value: 0.9670138888888888 and parameters: {'ref_cells': 76, 'guard_cells': 6, 'far': 0.0028964031408334895, 'margin': 1.3157502947884867}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,719] Trial 262 finished with value: 0.9809027777777778 and parameters: {'ref_cells': 71, 'guard_cells': 13, 'far': 0.0035126812128381964, 'margin': 1.368488975348994}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,745] Trial 263 finished with value: 0.9600694444444444 and parameters: {'ref_cells': 74, 'guard_cells': 3, 'far': 0.0032218801054926323, 'margin': 1.404466331765581}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,773] Trial 264 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 69, 'guard_cells': 8, 'far': 0.0036750233205065648, 'margin': 1.3400309850129957}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,799] Trial 265 finished with value: 0.9435763888888888 and parameters: {'ref_cells': 72, 'guard_cells': 11, 'far': 0.003953870738075617, 'margin': 1.2911204449660063}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,826] Trial 266 finished with value: 0.984375 and parameters: {'ref_cells': 70, 'guard_cells': 6, 'far': 0.003099084480963606, 'margin': 1.3573260981835418}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,866] Trial 267 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 75, 'guard_cells': 15, 'far': 0.0034206028116795227, 'margin': 1.3337217981998977}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,893] Trial 268 finished with value: 0.9800347222222222 and parameters: {'ref_cells': 77, 'guard_cells': 10, 'far': 0.00289090480806766, 'margin': 1.3775916271024147}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,916] Trial 269 finished with value: 0.9565972222222222 and parameters: {'ref_cells': 68, 'guard_cells': 2, 'far': 0.0036364507292570626, 'margin': 1.3081818232890898}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,943] Trial 270 finished with value: 0.9904513888888888 and parameters: {'ref_cells': 73, 'guard_cells': 7, 'far': 0.0033471427565084037, 'margin': 1.3532477003367887}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:03,975] Trial 271 finished with value: 0.9149305555555556 and parameters: {'ref_cells': 71, 'guard_cells': 7, 'far': 0.00338555279461041, 'margin': 1.2661639397450926}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,001] Trial 272 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 73, 'guard_cells': 4, 'far': 0.003132645439665562, 'margin': 1.3280438929727023}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,035] Trial 273 finished with value: 0.9661458333333334 and parameters: {'ref_cells': 67, 'guard_cells': 8, 'far': 0.0032562596930761517, 'margin': 1.3943937211501036}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,062] Trial 274 finished with value: 0.984375 and parameters: {'ref_cells': 74, 'guard_cells': 6, 'far': 0.0026969594496712834, 'margin': 1.3660065164937087}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,087] Trial 275 finished with value: 0.9878472222222222 and parameters: {'ref_cells': 70, 'guard_cells': 9, 'far': 0.0034424348101704414, 'margin': 1.3424892615876662}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,114] Trial 276 finished with value: 0.9635416666666666 and parameters: {'ref_cells': 70, 'guard_cells': 10, 'far': 0.003828247940859113, 'margin': 1.3091028846832655}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,142] Trial 277 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 69, 'guard_cells': 13, 'far': 0.002990712381112551, 'margin': 1.3787750933846106}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,170] Trial 278 finished with value: 0.9791666666666666 and parameters: {'ref_cells': 67, 'guard_cells': 9, 'far': 0.003188433185199523, 'margin': 1.3285635945637408}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,201] Trial 279 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 71, 'guard_cells': 1, 'far': 0.0033129763154169647, 'margin': 1.3534811305981687}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,233] Trial 280 finished with value: 0.9331597222222222 and parameters: {'ref_cells': 76, 'guard_cells': 8, 'far': 0.0034429790090407, 'margin': 1.284259176310772}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,276] Trial 281 finished with value: 0.9600694444444444 and parameters: {'ref_cells': 69, 'guard_cells': 3, 'far': 0.002676140535233505, 'margin': 1.4005307631746595}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,304] Trial 282 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 72, 'guard_cells': 11, 'far': 0.004165191223316581, 'margin': 1.3412593146807077}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,332] Trial 283 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 66, 'guard_cells': 14, 'far': 0.002977886155115566, 'margin': 1.3686573871111616}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,358] Trial 284 finished with value: 0.9748263888888888 and parameters: {'ref_cells': 75, 'guard_cells': 7, 'far': 0.0038019765016741106, 'margin': 1.3179537377846429}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,387] Trial 285 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 71, 'guard_cells': 4, 'far': 0.0034630171346412934, 'margin': 1.3545572669107946}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,415] Trial 286 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 68, 'guard_cells': 10, 'far': 0.0032772869830809846, 'margin': 1.3827353855835058}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,445] Trial 287 finished with value: 0.9826388888888888 and parameters: {'ref_cells': 65, 'guard_cells': 6, 'far': 0.0028076761851704517, 'margin': 1.332040320394683}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,473] Trial 288 finished with value: 0.9565972222222222 and parameters: {'ref_cells': 73, 'guard_cells': 16, 'far': 0.003762604322717162, 'margin': 1.3033318616739602}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,504] Trial 289 finished with value: 0.9869791666666666 and parameters: {'ref_cells': 70, 'guard_cells': 12, 'far': 0.009550916777502742, 'margin': 1.3586399625331307}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,530] Trial 290 finished with value: 0.9817708333333334 and parameters: {'ref_cells': 72, 'guard_cells': 0, 'far': 0.0031563074384404984, 'margin': 1.3365364645479254}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,558] Trial 291 finished with value: 0.9774305555555556 and parameters: {'ref_cells': 68, 'guard_cells': 8, 'far': 0.0035263399344118984, 'margin': 1.3738163342028566}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,588] Trial 292 finished with value: 0.9609375 and parameters: {'ref_cells': 74, 'guard_cells': 9, 'far': 0.003981096878012281, 'margin': 1.407938202756611}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,631] Trial 293 finished with value: 0.9756944444444444 and parameters: {'ref_cells': 77, 'guard_cells': 4, 'far': 0.003331186263063401, 'margin': 1.3220920562651743}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,659] Trial 294 finished with value: 0.9878472222222222 and parameters: {'ref_cells': 70, 'guard_cells': 11, 'far': 0.003063766768570672, 'margin': 1.352450282612275}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,687] Trial 295 finished with value: 0.9913194444444444 and parameters: {'ref_cells': 66, 'guard_cells': 13, 'far': 0.0030392122886063223, 'margin': 1.35700237934882}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,722] Trial 296 finished with value: 0.9730902777777778 and parameters: {'ref_cells': 64, 'guard_cells': 14, 'far': 0.003044818781682141, 'margin': 1.3848308893445949}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,754] Trial 297 finished with value: 0.9852430555555556 and parameters: {'ref_cells': 66, 'guard_cells': 12, 'far': 0.0028724063667360106, 'margin': 1.3635606115908907}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,783] Trial 298 finished with value: 0.9696180555555556 and parameters: {'ref_cells': 68, 'guard_cells': 11, 'far': 0.0031475531771124584, 'margin': 1.3934233260584934}. Best is trial 221 with value: 0.9921875.
# [I 2025-03-03 22:34:04,812] Trial 299 finished with value: 0.9861111111111112 and parameters: {'ref_cells': 75, 'guard_cells': 16, 'far': 0.0036356516607444042, 'margin': 1.3543530365674412}. Best is trial 221 with value: 0.9921875.
# Meilleurs paramètres : {'ref_cells': 73, 'guard_cells': 6, 'far': 0.0035246599795660883, 'margin': 1.3494764675685749}
# Accuracy sur l'ensemble d'entraînement : 0.99219
# Accuracy sur l'ensemble de test : 0.96181

# %%
def visualize_train_test_results(train_data, test_data, train_title="Train Set Results", test_title="Test Set Results"):
    """
    Visualizes the train and test datasets with their respective CA-CFAR results.

    Parameters:
        train_data (DataFrame): DataFrame containing 'timestamp', 'kpi', 'threshold', and 'anomaly' columns for the train set.
        test_data (DataFrame): DataFrame containing 'timestamp', 'kpi', 'threshold', and 'anomaly' columns for the test set.
        train_title (str): Title for the train set plot.
        test_title (str): Title for the test set plot.
    """
    # Ensure the train and test data are sorted by timestamp
    train_data = train_data.sort_values(by="timestamp")
    test_data = test_data.sort_values(by="timestamp")

    # Create the figure for the train set
    train_fig = go.Figure()

    # Add KPI line for the train set
    train_fig.add_trace(go.Scatter(
        x=train_data['timestamp'],
        y=train_data['kpi'],
        mode='lines',
        name='Train KPI',
        line=dict(color='blue', width=1.5),
        opacity=0.8
    ))

    # Add anomalies for the train set
    train_anomalies = train_data[train_data['anomaly'] == 1]
    train_fig.add_trace(go.Scatter(
        x=train_anomalies['timestamp'],
        y=train_anomalies['kpi'],
        mode='markers',
        name='Train Anomalies',
        marker=dict(color='red', size=8, symbol='circle'),
        hoverinfo='x+y'
    ))

    # Add dynamic threshold for the train set
    train_fig.add_trace(go.Scatter(
        x=train_data['timestamp'],
        y=train_data['threshold'],
        mode='lines',
        name='Train Threshold',
        line=dict(color='green', width=2, dash='dash')
    ))

    # Update layout for train plot
    train_fig.update_layout(
        title=train_title,
        xaxis_title='Time',
        yaxis_title='KPI Value',
        template='plotly_white',
        legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1)
    )

    # Create the figure for the test set
    test_fig = go.Figure()

    # Add KPI line for the test set
    test_fig.add_trace(go.Scatter(
        x=test_data['timestamp'],
        y=test_data['kpi'],
        mode='lines',
        name='Test KPI',
        line=dict(color='purple', width=1.5),
        opacity=0.8
    ))

    # Add anomalies for the test set
    test_anomalies = test_data[test_data['anomaly'] == 1]
    test_fig.add_trace(go.Scatter(
        x=test_anomalies['timestamp'],
        y=test_anomalies['kpi'],
        mode='markers',
        name='Test Anomalies',
        marker=dict(color='orange', size=8, symbol='circle'),
        hoverinfo='x+y'
    ))

    # Add dynamic threshold for the test set
    test_fig.add_trace(go.Scatter(
        x=test_data['timestamp'],
        y=test_data['threshold'],
        mode='lines',
        name='Test Threshold',
        line=dict(color='green', width=2, dash='dash')
    ))

    # Update layout for test plot
    test_fig.update_layout(
        title=test_title,
        xaxis_title='Time',
        yaxis_title='KPI Value',
        template='plotly_white',
        legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1)
    )

    # Show both plots
    train_fig.show()
    test_fig.show()

# %%
results_split["train_data"] = ca_cfar(results_split["train_data"], **results_split["best_params"])

# %%
visualize_train_test_results(
    results_split["train_data"], 
    results_split["test_data"], 
    train_title="CA-CFAR Results on Train Set", 
    test_title="CA-CFAR Results on Test Set"
)

# %%
def adjust_test_timestamps(train_data, test_data):
    """
    Adjust the timestamps of the test set to maintain continuity with the train set.
    
    Parameters:
        train_data (DataFrame): The train dataset containing the 'timestamp' column.
        test_data (DataFrame): The test dataset containing the 'timestamp' column.

    Returns:
        DataFrame: The adjusted test dataset.
    """
    # Convert timestamp column to datetime if it's not already
    train_data['timestamp'] = pd.to_datetime(train_data['timestamp'])
    test_data['timestamp'] = pd.to_datetime(test_data['timestamp'])
    
    # Get the last timestamp from the train set
    last_train_timestamp = train_data['timestamp'].max()
    
    # Calculate the offset between the last train timestamp and the first test timestamp
    time_delta = pd.Timedelta(minutes=1)  # Assuming data frequency is 1 minute
    
    # Adjust the test timestamps to start after the last train timestamp
    test_data = test_data.copy()
    test_data['timestamp'] = [last_train_timestamp + (i + 1) * time_delta for i in range(len(test_data))]
    
    return test_data

results_split["test_data"] = adjust_test_timestamps(results_split["train_data"], results_split["test_data"])

visualize_train_test_results(
    results_split["train_data"], 
    results_split["test_data"], 
    train_title="CA-CFAR Results on Train Set", 
    test_title="CA-CFAR Results on Test Set with Adjusted Timestamps"
)
